# %%
import pandas as pd
import graphlot as grpl
import genopyc as gp
import networkx as nx

# %% [markdown]
# # Load the data

# %%
secretome_deg = pd.read_excel('../data/CORRECT_Secretome profile human degenerated NPC.xlsx')
secretome_healthy = pd.read_excel('../data/Secretome profile human trauma NPC_(healthy).xlsx')
interactome = pd.read_csv('../data/HIPPIE-current.mitab.txt',sep='\t')
# Out:
# /tmp/ipykernel_2451/730401835.py:3: DtypeWarning: Columns (12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactome = pd.read_csv('../data/HIPPIE-current.mitab.txt',sep='\t')

# %%
interactome = interactome[interactome.columns[:2]]
interactome[interactome.columns[0]] = interactome[interactome.columns[0]].apply(lambda x: x.replace('entrez gene:',''))
interactome[interactome.columns[1]] = interactome[interactome.columns[1]].apply(lambda x: x.replace('entrez gene:',''))

# %%
interactome = interactome[~interactome['ID Interactor A'].str.contains('-')]
interactome = interactome[~interactome['ID Interactor B'].str.contains('-')]
interactome = interactome.astype(int)

# %%
interactome['ID_A_symbol'] = gp.geneId_mapping(interactome['ID Interactor A'].tolist(),'entrez','symbol')
interactome['ID_B_symbol'] = gp.geneId_mapping(interactome['ID Interactor B'].tolist(),'entrez','symbol')

# %%
interactome.dropna(inplace=True)

# %% [markdown]
# # Parse the files

# %%
cols_secretome = secretome_deg.iloc[3]
secretome_healthy.columns = cols_secretome
secretome_deg.columns = cols_secretome

# %%
secretome_healthy = secretome_healthy[4:]
secretome_deg = secretome_deg[4:]

# %%
secretome_deg.head()
# Out:
# 3             Analyte:        IL4     IL1B     IL1A       IFNG       CSF3  \
# 4  AL-HD615-No Treat_1  16.334167  2.12132  2.12132   7.212489  22.839549
# 5  AL-HD615-No Treat_2  16.334167  2.12132  2.12132   7.212489  22.839549
# 6  AL-HD615-No Treat_3  16.334167  2.12132  2.12132  14.509159  22.839549
# 7       AL-HD615-IL4_1       5500  2.12132  2.12132  24.001167  22.839549
# 8       AL-HD615-IL4_2       5500  2.12132  2.12132  30.348239  22.839549
#
# 3     KITLG      IL17F       IL7       IL16  ...      TGFB1     CCL11  \
# 4  0.791925  16.263456  3.677521  10.181358  ...  48.083261   2.12132
# 5  0.812623  16.263456  4.317971  13.363359  ...  48.083261  8.476072
# 6  1.018896  16.263456  4.610939  15.632614  ...  48.083261   2.12132
# 7  1.434049  27.124493  9.613736  20.434606  ...  48.083261   2.12132
# 8  1.195813   27.21716  6.329551    5.11236  ...  48.083261   2.12132
#
# 3       VCAM1       TIMP1   MMP2       MMP9     CCL5      ICAM1    SERPINE1  \
# 4   88.714759  620.340105  16600    2.12132  2.12132  56.605186  190.672389
# 5   113.23831   567.71186  16600  21.517642  2.12132  92.751246  206.990512
# 6  111.471805  623.994232  16600    9.80383  2.12132  91.390998  265.460146
# 7  334.377147  749.644061  16600    2.12132  2.12132  69.143543  299.466436
# 8   362.34979  503.833948  16600  17.307313  2.12132  74.894257  254.113157
#
# 3     DEFB1
# 4   2.12132
# 5  4.285474
# 6  4.910147
# 7  3.977022
# 8   2.12132
#
# [5 rows x 74 columns]

# %%
secretome_deg
# Out:
# 3              Analyte:          IL4        IL1B      IL1A       IFNG  \
# 4   AL-HD615-No Treat_1    16.334167     2.12132   2.12132   7.212489
# 5   AL-HD615-No Treat_2    16.334167     2.12132   2.12132   7.212489
# 6   AL-HD615-No Treat_3    16.334167     2.12132   2.12132  14.509159
# 7        AL-HD615-IL4_1         5500     2.12132   2.12132  24.001167
# 8        AL-HD615-IL4_2         5500     2.12132   2.12132  30.348239
# ..                  ...          ...         ...       ...        ...
# 75         AL-HD675-IL4         5500     2.12132   2.12132  28.254954
# 76        AL-HD675-IL10    16.334167     2.12132   2.12132  11.466285
# 77         AL-HD675-IL1    35.013246  438.349415  2.423972  20.398953
# 78     AL-HD675-IL1+IL4  5019.265472  321.206514  4.565344  38.264092
# 79    AL-HD675-IL1+IL10  1814.452568  210.248526  2.547812   23.80388
#
# 3         CSF3     KITLG      IL17F       IL7       IL16  ...      TGFB1  \
# 4    22.839549  0.791925  16.263456  3.677521  10.181358  ...  48.083261
# 5    22.839549  0.812623  16.263456  4.317971  13.363359  ...  48.083261
# 6    22.839549  1.018896  16.263456  4.610939  15.632614  ...  48.083261
# 7    22.839549  1.434049  27.124493  9.613736  20.434606  ...  48.083261
# 8    22.839549  1.195813   27.21716  6.329551    5.11236  ...  48.083261
# ..         ...       ...        ...       ...        ...  ...        ...
# 75   22.839549  1.473322  24.054552  7.200225   5.820328  ...  48.083261
# 76   22.839549  0.494975  16.263456  5.276014    5.04451  ...  48.083261
# 77  406.265026  2.264873  16.263456  6.424684  34.933461  ...  48.083261
# 78  387.096714  2.992257  29.703529  9.124147  39.609576  ...  48.083261
# 79  279.828826  1.903229  21.914514  6.111637  30.500823  ...  48.083261
#
# 3      CCL11       VCAM1       TIMP1          MMP2       MMP9        CCL5  \
# 4    2.12132   88.714759  620.340105         16600    2.12132     2.12132
# 5   8.476072   113.23831   567.71186         16600  21.517642     2.12132
# 6    2.12132  111.471805  623.994232         16600    9.80383     2.12132
# 7    2.12132  334.377147  749.644061         16600    2.12132     2.12132
# 8    2.12132   362.34979  503.833948         16600  17.307313     2.12132
# ..       ...         ...         ...           ...        ...         ...
# 75  3.578541   93.802798        1900         16600    2.44965    3.389407
# 76   2.47526    21.84696        1900  16484.575504   2.826139    3.361477
# 77  3.077584  364.861568        1900         16600   2.675259  163.335185
# 78   2.12132  1155.67953        1900         16600    2.12132   96.263076
# 79   2.12132  323.688583        1900         16600   3.280661  134.485175
#
# 3        ICAM1     SERPINE1     DEFB1
# 4    56.605186   190.672389   2.12132
# 5    92.751246   206.990512  4.285474
# 6    91.390998   265.460146  4.910147
# 7    69.143543   299.466436  3.977022
# 8    74.894257   254.113157   2.12132
# ..         ...          ...       ...
# 75   59.466941   650.547391   2.12132
# 76   63.160337  1135.644702   2.12132
# 77  368.082444   432.487775  7.276256
# 78  222.295362    424.43717  5.234827
# 79  288.873905   344.488458  4.600817
#
# [76 rows x 74 columns]

# %%
secretome_healthy.head()
# Out:
# 3            Analyte:         IL4        IL1B     IL1A       IFNG        CSF3  \
# 4  142_S1_Ctrl_DONOR1   16.334167     2.12132  2.12132   7.212489   22.839549
# 5   143_S2_IL4_DONOR1  321.736335     2.12132  2.12132   7.212489   22.839549
# 6   144_S3_IL1_DONOR1   37.822216  151.389399  2.12132   20.36198  177.608311
# 7  145_S4_Ctrl_DONOR2   16.334167     2.12132  2.12132   7.212489   32.315944
# 8   146_S5_IL4_DONOR2  475.581854     2.12132  2.12132  22.212977   22.839549
#
# 3     KITLG      IL17F       IL7      IL16  ...      TGFB1    CCL11  \
# 4  0.494975  16.263456   2.12132   2.12132  ...  68.732602  2.12132
# 5  0.935614  16.263456   2.12132   2.12132  ...  77.537051  2.12132
# 6  4.676315  16.263456  4.928649  32.40502  ...  48.083261  2.12132
# 7  0.494975  16.263456   2.12132   2.12132  ...  87.680766  2.12132
# 8   1.20644  16.263456   2.12132   2.12132  ...  48.083261  2.12132
#
# 3       VCAM1        TIMP1         MMP2      MMP9       CCL5      ICAM1  \
# 4  123.978857  2052.168154  1803.527686   2.12132   6.908848  32.498471
# 5  161.590714  2114.868815  1641.488057   2.12132   6.140666  28.228864
# 6  470.772638  2098.493638  1418.574411   7.87869  27.877928  185.22572
# 7    5.734342   2217.82799  3093.846109  3.596343   4.331521  26.475898
# 8    6.965183  2314.622224  2631.511866   2.12132    2.12132  23.351559
#
# 3     SERPINE1      DEFB1
# 4  2447.506576  16.385538
# 5  2148.651793  11.226913
# 6   612.595493  11.872407
# 7  4448.981853   3.584128
# 8  3496.981268    3.61337
#
# [5 rows x 74 columns]

# %% [markdown]
# # CHECK IF ALL THE PROTEINS OF THE SECRETOME ARE IN THE INTERACTOME FILE

# %%
interactome_proteins = set(interactome['ID_A_symbol'].tolist() + interactome['ID_B_symbol'].tolist())

# %% [markdown]
# Modified names
#
# - Eotaxin -> ccl11
# - rantes -> ccl5
# - tweak -> tnfsf12
# - srankl -> tnfsf11
# - il1ra -> il1rn
# - G-CSF -> CSF3
# - SCF -> KITLG
# - TNFA -> TNF
# - FGF BASIC -> FGF2
# - IL1RA -> IL1RN
# - GM CSF -> CSF2
# - M CSF -> CSF3
# - IL12 -> IL12A
# - CTACK -> CCL27
# - IP10 -> CXCL10
# - GROA -> CXCL1
# - TNF10 -> TNFSF10
# - ST2 -> IL1RL1
# - SRANK-L -> TNFSF11
# - VEGF -> VEGFA
# - TGF-b1 -> TGFB1
# - rantes -> ccl5

# %%
print(f"the proteins: {[g for g in cols_secretome if g not in interactome_proteins]} are not in the interactome")
# Out:
# the proteins: ['Analyte:', 'CCL4', 'IL8'] are not in the interactome

# %% [markdown]
# # CREATE GUILD INPUTS
#
# ## INTERACTOME
#
# Here I will create the network file of the interactome by keeping the largest connected component

# %%
interactome_net = nx.from_pandas_edgelist(interactome[['ID_A_symbol','ID_B_symbol']],source='ID_A_symbol',target='ID_B_symbol')
interactome_net

# %%
largest_cc = max(nx.connected_components(interactome_net), key=len)

# %%
interactome_cc = nx.subgraph(interactome_net,largest_cc)

# %%
interactome_pandas = nx.to_pandas_edgelist(interactome_cc)
interactome_pandas
# Out:
#          source   target
# 0       ALDH1A1  ALDH1A1
# 1       ALDH1A1    NUPR1
# 2       ALDH1A1    ALDH2
# 3       ALDH1A1     POT1
# 4       ALDH1A1     NOS2
# ...         ...      ...
# 775831     VNN1    VNN3P
# 775832    KLK14   OR13C3
# 775833  SPDYE7P   SPDYE3
# 775834    GADL1   OR10A4
# 775835    TSPY3    TSPY8
#
# [775836 rows x 2 columns]

# %%
interactome_pandas.insert(1,'score',1)

# %%
interactome_pandas.head()
# Out:
#     source  score   target
# 0  ALDH1A1      1  ALDH1A1
# 1  ALDH1A1      1    NUPR1
# 2  ALDH1A1      1    ALDH2
# 3  ALDH1A1      1     POT1
# 4  ALDH1A1      1     NOS2

# %% [markdown]
# ## SEEDS FILES
#
# Healthy:control, il1 and il4
#
# Degenerated: control, il1, il4, il1+il4 a
# nd il1+il10

# %%
secretome_deg = secretome_deg.iloc[58:]

# %%
secretome_deg.set_index('Analyte:',inplace=True)

# %%
secretome_deg = secretome_deg.drop(['CCL4', 'IL8'],axis=1)

# %%
def minmax_scale_list(data, min_value=0, max_value=1):
    """
    Min-max scale a list of numbers to a specified range.

    Parameters:
        data (list): The list of numbers to be scaled.
        min_value (float): The minimum value of the desired range (default: 0).
        max_value (float): The maximum value of the desired range (default: 1).

    Returns:
        list: The scaled list of numbers.
    """
    min_data = min(data)
    max_data = max(data)
    scaled_data = [(x - min_data) / (max_data - min_data) * (max_value - min_value) + min_value for x in data]
    return scaled_data

# %% [markdown]
# # How much are connected those nodes
#
# To run guild we need connections otherwise we won't have any passage

# %%
secretome_proteins = secretome_deg.columns.tolist()
secretome_network = nx.subgraph(interactome_net,secretome_proteins)

# %%
grpl.visualize_network(secretome_network)
print("not all the nodes are connected")
# Out:
# not all the nodes are connected

# %% [markdown]
# ## in this snipped I will find the shortest paths between the seeds in order to "force" the connections

# %%
shortest_paths = {}
for node1 in secretome_proteins:
    for node2 in secretome_proteins:
        if node1 != node2:
            shortest_paths[(node1, node2)] = nx.shortest_path(interactome_net, source=node1, target=node2)

# %%
all_nodes = set()
for path in shortest_paths.values():
    all_nodes.update(path)
all_nodes
# Out:
# {'A2M',
#  'ABL1',
#  'ACKR1',
#  'ACKR2',
#  'ACKR4',
#  'ACP5',
#  'ACTA2',
#  'ACTB',
#  'ACTG1',
#  'ACTN4',
#  'ADAM17',
#  'ADAM19',
#  'ADAMTS1',
#  'ADAMTS2',
#  'ADAMTSL4',
#  'ADGRL1',
#  'ADGRV1',
#  'ADRB1',
#  'ADRB2',
#  'AGGF1',
#  'AGPAT5',
#  'AHNAK2',
#  'AIFM1',
#  'AKT1',
#  'ALDH18A1',
#  'AMIGO1',
#  'ANKRD46',
#  'ANP32A',
#  'ANP32B',
#  'ANXA2',
#  'APC',
#  'API5',
#  'APOE',
#  'APP',
#  'AQP3',
#  'AQP6',
#  'AREG',
#  'ARL5B',
#  'ARMC8',
#  'ASGR2',
#  'ASPH',
#  'ATP12A',
#  'ATP13A1',
#  'ATP1A3',
#  'ATP2B4',
#  'ATP5IF1',
#  'ATP8B2',
#  'B3GAT3',
#  'B4GALT5',
#  'BAG4',
#  'BCAN',
#  'BEX2',
#  'BGN',
#  'BID',
#  'BIRC2',
#  'BIRC3',
#  'BMP4',
#  'BMP5',
#  'BMPR1A',
#  'BMPR2',
#  'BRD4',
#  'BSCL2',
#  'BSG',
#  'C16orf92',
#  'C1GALT1C1',
#  'C20orf141',
#  'CALM1',
#  'CALR',
#  'CAMK1',
#  'CANX',
#  'CAPN1',
#  'CASK',
#  'CASP1',
#  'CASP3',
#  'CASP8',
#  'CBL',
#  'CBLB',
#  'CBLC',
#  'CCDC33',
#  'CCDC8',
#  'CCL11',
#  'CCL13',
#  'CCL14',
#  'CCL17',
#  'CCL19',
#  'CCL2',
#  'CCL20',
#  'CCL21',
#  'CCL22',
#  'CCL23',
#  'CCL27',
#  'CCL3',
#  'CCL4L1',
#  'CCL5',
#  'CCL7',
#  'CCN2',
#  'CCNA2',
#  'CCR1',
#  'CCR10',
#  'CCR2',
#  'CCR3',
#  'CCR4',
#  'CCR5',
#  'CCR6',
#  'CCR7',
#  'CCR8',
#  'CCR9',
#  'CCZ1',
#  'CD14',
#  'CD151',
#  'CD28',
#  'CD33',
#  'CD4',
#  'CD40',
#  'CD44',
#  'CD53',
#  'CD63',
#  'CDC42',
#  'CDC5L',
#  'CDC6',
#  'CDH1',
#  'CDK1',
#  'CDK15',
#  'CDK9',
#  'CDKN1A',
#  'CEBPB',
#  'CEBPE',
#  'CEP126',
#  'CERK',
#  'CERS4',
#  'CFTR',
#  'CHD1L',
#  'CHD4',
#  'CHM',
#  'CHRNA5',
#  'CISD2',
#  'CIT',
#  'CLCF1',
#  'CLCN3',
#  'CLEC11A',
#  'CLEC7A',
#  'CLU',
#  'CMA1',
#  'CNOT1',
#  'CNTF',
#  'CNTFR',
#  'COL14A1',
#  'COL18A1',
#  'COL1A1',
#  'COL2A1',
#  'COL4A2',
#  'COL4A3',
#  'COL4A5',
#  'COL6A2',
#  'COL7A1',
#  'COPB1',
#  'COPS3',
#  'COPS5',
#  'COPS6',
#  'CREB3L1',
#  'CRYAB',
#  'CS',
#  'CSF1',
#  'CSF1R',
#  'CSF2',
#  'CSF2RA',
#  'CSF2RB',
#  'CSF3',
#  'CSF3R',
#  'CSNK2A1',
#  'CSNK2B',
#  'CSPG4',
#  'CST5',
#  'CTPS2',
#  'CTSB',
#  'CTSG',
#  'CUL3',
#  'CUX1',
#  'CX3CL1',
#  'CX3CR1',
#  'CXCL1',
#  'CXCL10',
#  'CXCL11',
#  'CXCL12',
#  'CXCL13',
#  'CXCL16',
#  'CXCL17',
#  'CXCL2',
#  'CXCL3',
#  'CXCL5',
#  'CXCL6',
#  'CXCL8',
#  'CXCL9',
#  'CXCR1',
#  'CXCR2',
#  'CXCR3',
#  'CXCR4',
#  'CXCR5',
#  'CXCR6',
#  'CYLD',
#  'CYSRT1',
#  'DAD1',
#  'DAG1',
#  'DCAF4',
#  'DCN',
#  'DDX11L8',
#  'DDX19B',
#  'DDX39A',
#  'DEFB1',
#  'DHRS7',
#  'DIABLO',
#  'DIP2A',
#  'DNAAF5',
#  'DPP4',
#  'DPP8',
#  'DSTYK',
#  'DUSP7',
#  'DYNLL1',
#  'EBI3',
#  'ECH1',
#  'EDA',
#  'EEF1A1',
#  'EEF1B2',
#  'EEF1G',
#  'EFTUD2',
#  'EGF',
#  'EGFR',
#  'EIF3E',
#  'EIF3I',
#  'ELANE',
#  'ELAVL1',
#  'ELN',
#  'EME1',
#  'ENO1',
#  'EP300',
#  'EPHB2',
#  'EPOR',
#  'ERBB2',
#  'ERBB3',
#  'ERBB4',
#  'EREG',
#  'ERGIC2',
#  'ESR1',
#  'ESR2',
#  'EWSR1',
#  'EXT1',
#  'EZH2',
#  'EZR',
#  'F11R',
#  'F13A1',
#  'F2R',
#  'FADD',
#  'FAM118B',
#  'FAM20C',
#  'FASLG',
#  'FAT4',
#  'FBXO2',
#  'FBXO6',
#  'FBXO7',
#  'FBXW7',
#  'FCGR2A',
#  'FEM1B',
#  'FEZ1',
#  'FGF2',
#  'FGFR1',
#  'FGFR2',
#  'FGFR3',
#  'FGFR4',
#  'FHL2',
#  'FHL3',
#  'FIBP',
#  'FKRP',
#  'FLT1',
#  'FN1',
#  'FNDC5',
#  'FOS',
#  'FOXM1',
#  'FST',
#  'FSTL1',
#  'FTH1',
#  'FYN',
#  'FZR1',
#  'GALNT12',
#  'GANAB',
#  'GFER',
#  'GGH',
#  'GHR',
#  'GIPC1',
#  'GJA8',
#  'GJB1',
#  'GLS',
#  'GMCL1',
#  'GNGT1',
#  'GOLGA2',
#  'GOPC',
#  'GORASP2',
#  'GOT1',
#  'GPS1',
#  'GRB2',
#  'GRIN2B',
#  'GRN',
#  'H2BC8',
#  'H4C16',
#  'HADHB',
#  'HAP1',
#  'HAPLN1',
#  'HBEGF',
#  'HEATR1',
#  'HECTD3',
#  'HGS',
#  'HIF1A',
#  'HLA-B',
#  'HLA-C',
#  'HLA-DQA1',
#  'HM13',
#  'HMGB1',
#  'HNRNPA1',
#  'HNRNPA2B1',
#  'HNRNPH1',
#  'HNRNPU',
#  'HOOK2',
#  'HOXA1',
#  'HRAS',
#  'HSP90AA1',
#  'HSP90B1',
#  'HSPA5',
#  'HSPA8',
#  'HSPA9',
#  'HSPB1',
#  'HSPG2',
#  'HTRA2',
#  'HTT',
#  'ICAM1',
#  'IDE',
#  'IFIT3',
#  'IFNA2',
#  'IFNA5',
#  'IFNAR1',
#  'IFNG',
#  'IFNGR1',
#  'IFNGR2',
#  'IGFBP3',
#  'IGFBP5',
#  'IGFBP7',
#  'IGHG1',
#  'IKBKB',
#  'IKBKG',
#  'IKZF4',
#  'IL10',
#  'IL10RA',
#  'IL10RB',
#  'IL11',
#  'IL12A',
#  'IL12RB1',
#  'IL13',
#  'IL13RA2',
#  'IL15',
#  'IL15RA',
#  'IL16',
#  'IL17A',
#  'IL17F',
#  'IL17RA',
#  'IL18',
#  'IL1A',
#  'IL1B',
#  'IL1R1',
#  'IL1R2',
#  'IL1RAP',
#  'IL1RL1',
#  'IL1RN',
#  'IL2',
#  'IL20',
#  'IL20RA',
#  'IL20RB',
#  'IL22',
#  'IL22RA1',
#  'IL22RA2',
#  'IL2RA',
#  'IL2RB',
#  'IL2RG',
#  'IL33',
#  'IL4',
#  'IL4R',
#  'IL5',
#  'IL5RA',
#  'IL6',
#  'IL6R',
#  'IL6ST',
#  'IL7',
#  'IL7R',
#  'IL9',
#  'IL9R',
#  'ILF3',
#  'INHBE',
#  'INTS1',
#  'INTS4',
#  'IRAK4',
#  'IRF5',
#  'ISG15',
#  'ITGA4',
#  'ITGA8',
#  'ITGAM',
#  'ITGAV',
#  'ITGB1',
#  'ITGB3',
#  'JAGN1',
#  'JAK1',
#  'JAK2',
#  'JAK3',
#  'KASH5',
#  'KAT5',
#  'KDR',
#  'KEAP1',
#  'KIF14',
#  'KIF1B',
#  'KIT',
#  'KITLG',
#  'KLK10',
#  'KLK2',
#  'KLK5',
#  'KLK6',
#  'KRT18',
#  'KRT31',
#  'KRTAP1-3',
#  'KRTAP10-8',
#  'KRTAP12-3',
#  'LAMA1',
#  'LAMC2',
#  'LAPTM4B',
#  'LARP4B',
#  'LDLR',
#  'LEMD3',
#  'LGALS1',
#  'LGALS3',
#  'LIF',
#  'LIFR',
#  'LMNA',
#  'LMO7',
#  'LRIF1',
#  'LRP1',
#  'LRP2',
#  'LRP4',
#  'LRP5',
#  'LRRC25',
#  'LRRK2',
#  'LTF',
#  'LYN',
#  'LYPLA1',
#  'MAEA',
#  'MAGEA11',
#  'MAP1LC3B',
#  'MAP2K1',
#  'MAP3K1',
#  'MAP3K7',
#  'MAP4K4',
#  'MAP7',
#  'MAPK1',
#  'MAPK3',
#  'MBLAC2',
#  'MBNL1',
#  'MBP',
#  'MBTPS1',
#  'MCM2',
#  'MCM3',
#  'MCM7',
#  'MCRIP2',
#  'MDM2',
#  'MED8',
#  'MEOX2',
#  'MET',
#  'MGAT1',
#  'MID2',
#  'MIF',
#  'MMP1',
#  'MMP13',
#  'MMP14',
#  'MMP17',
#  'MMP2',
#  'MMP3',
#  'MMP7',
#  'MMP9',
#  'MSN',
#  'MTDH',
#  'MTUS2',
#  'MUC1',
#  'MYC',
#  'MYCBP2',
#  'MYD88',
#  'MYH9',
#  'MYO18A',
#  'MYOC',
#  'NCALD',
#  'NCBP2',
#  'NCBP3',
#  'NCK1',
#  'NDEL1',
#  'NDUFAF1',
#  'NEDD4',
#  'NEFL',
#  'NEK4',
#  'NF2',
#  'NFKB1',
#  'NGF',
#  'NGFR',
#  'NMT1',
#  'NMU',
#  'NOS2',
#  'NOTCH2NLA',
#  'NPM1',
#  'NR3C1',
#  'NRAS',
#  'NRG1',
#  'NRP1',
#  'NTAQ1',
#  'NTRK1',
#  'NUDT3',
#  'OSM',
#  'OSMR',
#  'PABPC1',
#  'PAK1',
#  'PAK2',
#  'PAK4',
#  'PALB2',
#  'PARVG',
#  'PASK',
#  'PATZ1',
#  'PAXIP1',
#  'PCDH1',
#  'PCLAF',
#  'PDCD6IP',
#  'PDF',
#  'PDGFRA',
#  'PDGFRB',
#  'PDIA3',
#  'PDLIM7',
#  'PEAK1',
#  'PEDS1-UBE2V1',
#  'PF4',
#  'PF4V1',
#  'PGLYRP1',
#  'PHB1',
#  'PIGR',
#  'PIGU',
#  'PIK3CD',
#  'PIK3R1',
#  'PIK3R2',
#  'PINK1',
#  'PKM',
#  'PLEC',
#  'PLG',
#  'PLXNA2',
#  'PLXNA3',
#  'PMPCB',
#  'POT1',
#  'POTEF',
#  'PPBP',
#  'PPM1A',
#  'PPP1R12C',
#  'PPP2CA',
#  'PPP2R2B',
#  'PRG2',
#  'PRKACA',
#  'PRKCI',
#  'PRMT1',
#  'PRNP',
#  'PROK1',
#  'PRPF6',
#  'PRTN3',
#  'PSTPIP1',
#  'PTDSS1',
#  'PTMA',
#  'PTPN1',
#  'PTPN11',
#  'PTPN5',
#  'PTPN6',
#  'PTPRC',
#  'PTPRG',
#  'PTPRJ',
#  'PTPRS',
#  'PTPRZ1',
#  'QKI',
#  'RAB3B',
#  'RAC1',
#  'RACK1',
#  'RALBP1',
#  'RANBP10',
#  'RANBP9',
#  'RANGAP1',
#  'RB1',
#  'RBX1',
#  'RC3H1',
#  'RELA',
#  'RET',
#  'RETN',
#  'RHOBTB3',
#  'RHOU',
#  'RIF1',
#  'RIGI',
#  'RMC1',
#  'RNF123',
#  'RNF4',
#  'RPL31',
#  'RPL35A',
#  'RPL9',
#  'RPS18',
#  'RPS19',
#  'RPS4X',
#  'RPS6KA1',
#  'RPS6KA3',
#  'S100A13',
#  'S100A8',
#  'SACM1L',
#  'SARAF',
#  'SBF1',
#  'SCAMP1',
#  'SCNN1A',
#  'SDC1',
#  'SDC2',
#  'SDC4',
#  'SDCBP',
#  'SDF2L1',
#  'SEC22B',
#  'SERPINA3',
#  'SERPINB4',
#  'SERPINE1',
#  'SF3A2',
#  'SFTPC',
#  'SGCB',
#  'SGTA',
#  'SGTB',
#  'SH3GL2',
#  'SHARPIN',
#  'SHC1',
#  'SHMT2',
#  'SKP2',
#  'SLC16A2',
#  'SLC22A18',
#  'SLC30A1',
#  'SLC38A1',
#  'SLC39A10',
#  'SMARCB1',
#  'SNTA1',
#  'SNTG1',
#  'SNX27',
#  'SOCS1',
#  'SOCS3',
#  'SOCS5',
#  'SORL1',
#  'SORT1',
#  'SOS1',
#  'SP1',
#  'SPARC',
#  'SPDL1',
#  'SPN',
#  'SPOCK1',
#  'SPP1',
#  'SQSTM1',
#  'SRC',
#  'SREBF2',
#  'SRGN',
#  'SRRT',
#  'SRSF1',
#  'STAT1',
#  'STAT3',
#  'STAT5A',
#  'STAT5B',
#  'STAT6',
#  'STK11',
#  'STK16',
#  'STUB1',
#  'STX1A',
#  'SULF2',
#  'SUMO2',
#  'SUSD3',
#  'SYNCRIP',
#  'TAB1',
#  'TAF5L',
#  'TAMM41',
#  'TBK1',
#  'TBL1X',
#  'TCF7L2',
#  'TDGF1',
#  'TEX101',
#  'TFAP2A',
#  'TGFB1',
#  'TGFBR1',
#  'TGFBR2',
#  'THBS1',
#  'TIMMDC1',
#  'TIMP1',
#  'TIMP3',
#  'TIRAP',
#  'TK1',
#  'TLE5',
#  'TLR2',
#  'TLX3',
#  'TM2D3',
#  'TMED1',
#  'TMEM131L',
#  'TMEM192',
#  'TMEM205',
#  'TMEM237',
#  'TMEM87A',
#  'TMPO',
#  'TMPRSS2',
#  'TMX2',
#  'TNF',
#  'TNFAIP3',
#  'TNFAIP6',
#  'TNFRSF10A',
#  'TNFRSF10B',
#  'TNFRSF10D',
#  'TNFRSF11A',
#  'TNFRSF11B',
#  'TNFRSF14',
#  'TNFRSF25',
#  'TNFRSF9',
#  'TNFSF10',
#  'TNFSF11',
#  'TNFSF12',
#  'TNFSF14',
#  'TNIK',
#  'TP53',
#  'TPI1',
#  'TRAF1',
#  'TRAF2',
#  'TRAF3',
#  'TRAF3IP2',
#  'TRAF4',
#  'TRAF6',
#  'TRIM11',
#  'TRIM25',
#  'TRIM27',
#  'TRIM38',
#  'TRIP13',
#  'TRIP6',
#  'TUBA1A',
#  'TUBA4A',
#  'TUBB',
#  'TUBB3',
#  'TXN',
#  'TXNDC15',
#  'UBE2O',
#  'UBQLN1',
#  'UBQLN2',
#  'UBQLN4',
#  'UCN3',
#  'UNC119',
#  'UPK2',
#  'USF2',
#  'VAPA',
#  'VCAM1',
#  'VCAN',
#  'VEGFA',
#  'VHL',
#  'VIM',
#  'VIRMA',
#  'VTN',
#  'VWDE',
#  'WASF1',
#  'WFS1',
#  'XCL1',
#  'XCL2',
#  'XIAP',
#  'XPO5',
#  'XRCC3',
#  'YBX1',
#  'YBX3',
#  'YIPF6',
#  'YWHAE',
#  'YWHAZ',
#  'YY1',
#  'ZBTB16',
#  'ZC3H12A',
#  'ZDHHC17',
#  'ZER1',
#  'ZFP36',
#  'ZMYND19',
#  'ZNF408',
#  'ZNF581',
#  'ZNF587',
#  'ZNG1A'}

# %%
subnet_enriched = nx.subgraph(interactome_net,all_nodes)
grpl.visualize_network(subnet_enriched)

# %% [markdown]
# # create the new interactome as well as new seed files

# %%
subnet_enriched_sif = nx.to_pandas_edgelist(subnet_enriched)
subnet_enriched_sif.insert(1,'score',1)
subnet_enriched_sif
# Out:
#         source  score   target
# 0      GALNT12      1     MUC1
# 1      GALNT12      1      APP
# 2      GALNT12      1      RB1
# 3      GALNT12      1   BMPR1A
# 4      GALNT12      1    FBXW7
# ...        ...    ...      ...
# 15777   DIABLO      1    TRAF1
# 15778   LYPLA1      1   LYPLA1
# 15779  HSP90B1      1  HSP90B1
# 15780    TRAF1      1    TRAF1
# 15781     POT1      1     POT1
#
# [15782 rows x 3 columns]

# %%
subnet_enriched_sif.to_csv('../inputs/subnet_enriched.sif',index=None,header=None,sep = ' ')

# %%
experiments = ['No_Treat','-IL10','-IL1$','-IL4','IL1\+IL4','IL1\+IL10']

for i,exp in enumerate(experiments):
    print(i)
    df = secretome_deg[secretome_deg.index.str.contains(exp,regex=True)]
    secretome_proteins = df.columns.tolist()
    means = [df[col].mean() for col in df.columns.tolist()]
    scaled_means = minmax_scale_list(means)
    display(df)
    # Make a dictionary of cytokynes and values
    dictionary_of_means = dict(zip(df.columns.tolist(),scaled_means))
    
    # Force manually depending on the experiment
    if i == 1:
        dictionary_of_means['IL10'] = 1
    elif i == 2:
        dictionary_of_means['IL1'] = 1
    elif i == 3:
        dictionary_of_means['IL4'] = 1
    elif i == 4:
        dictionary_of_means['IL1'] = 1
        dictionary_of_means['IL4'] = 1
    elif i == 5:
        dictionary_of_means['IL1'] = 1
        dictionary_of_means['IL10'] = 1
    # Add the rest of the nodes
    
    for node in all_nodes:
        if node not in secretome_proteins:
            dictionary_of_means[node] = 0

    # Write the files
    with open('../inputs/secretome/degenerated_'+exp.replace('\\','').replace('$','')+'_nodes.txt','w') as f:
        for gene,score in dictionary_of_means.items():
            f.write(gene + ' ' + str(score) + ' ' + '\n')
# Out:
# 0
# 3                        IL4     IL1B     IL1A       IFNG       CSF3  \
# Analyte:
# AL-HD615-No_Treat  16.334167  2.12132  2.12132   9.644712  22.839549
# AL-HD665-No_Treat  16.334167  2.12132  2.12132  10.169779  22.839549
# AL-HD675-No_Treat  16.334167  2.12132  2.12132   7.212489  22.839549
#
# 3                     KITLG      IL17F       IL7       IL16      IL18  ...  \
# Analyte:                                                               ...
# AL-HD615-No_Treat  0.874481  16.263456  4.202144   13.05911  2.374642  ...
# AL-HD665-No_Treat  1.163326  16.263456  4.368673  11.513186  2.028707  ...
# AL-HD675-No_Treat  0.494975  16.263456  5.054099    2.12132  1.478775  ...
#
# 3                      TGFB1     CCL11       VCAM1       TIMP1   MMP2  \
# Analyte:
# AL-HD615-No_Treat  48.083261  4.239571  104.474958  604.015399  16600
# AL-HD665-No_Treat  48.083261   2.12132   23.252276        1900  16600
# AL-HD675-No_Treat  48.083261   2.12132   37.613553        1900  16600
#
# 3                       MMP9      CCL5       ICAM1     SERPINE1      DEFB1
# Analyte:
# AL-HD615-No_Treat  11.147597   2.12132   80.249143   221.041016   3.772314
# AL-HD665-No_Treat    2.12132  4.587019  142.308246   411.494811  14.339602
# AL-HD675-No_Treat   2.775807  5.391619   97.085206  2421.376833    2.12132
#
# [3 rows x 71 columns]
# 1
# 3                    IL4     IL1B     IL1A       IFNG       CSF3     KITLG  \
# Analyte:
# AL-HD615-IL10   23.51159  2.12132  2.12132  10.609799  22.839549  1.183071
# AL-HD665-IL10  26.241594  2.12132  2.12132  11.821619  22.839549  1.098112
# AL-HD675-IL10  16.334167  2.12132  2.12132  11.466285  22.839549  0.494975
#
# 3                  IL17F       IL7       IL16      IL18  ...      TGFB1  \
# Analyte:                                                 ...
# AL-HD615-IL10  16.263456  4.386326   18.56173  2.846589  ...  48.083261
# AL-HD665-IL10  16.263456  5.131409  19.493449  2.516201  ...  48.083261
# AL-HD675-IL10  16.263456  5.276014    5.04451  2.239715  ...  48.083261
#
# 3                CCL11       VCAM1        TIMP1          MMP2      MMP9  \
# Analyte:
# AL-HD615-IL10  2.12132  108.418647   702.627301         16600  9.754657
# AL-HD665-IL10  2.12132   22.219462  1885.052654         16600  5.735679
# AL-HD675-IL10  2.47526    21.84696         1900  16484.575504  2.826139
#
# 3                  CCL5       ICAM1     SERPINE1      DEFB1
# Analyte:
# AL-HD615-IL10   2.12132   85.978732   233.264785   3.712083
# AL-HD665-IL10  4.607011  137.831292   397.963415  13.321862
# AL-HD675-IL10  3.361477   63.160337  1135.644702    2.12132
#
# [3 rows x 71 columns]
# 2
# 3                   IL4        IL1B      IL1A       IFNG        CSF3  \
# Analyte:
# AL-HD615-IL1  19.295608  291.256274   2.12132    8.49103   22.839549
# AL-HD665-IL1   36.98887  574.901321   2.12132  22.054829  547.093886
# AL-HD675-IL1  35.013246  438.349415  2.423972  20.398953  406.265026
#
# 3                KITLG      IL17F       IL7       IL16      IL18  ...  \
# Analyte:                                                          ...
# AL-HD615-IL1  1.205391  16.263456  4.055407  22.376401  2.271954  ...
# AL-HD665-IL1  2.376918  16.263456  7.436237  35.634385  3.376092  ...
# AL-HD675-IL1  2.264873  16.263456  6.424684  34.933461  3.996861  ...
#
# 3                 TGFB1     CCL11       VCAM1       TIMP1   MMP2      MMP9  \
# Analyte:
# AL-HD615-IL1  48.083261  4.031431  140.636079  969.745844  16600  7.508059
# AL-HD665-IL1  48.083261   2.12132   22.540268        1900  16600   2.12132
# AL-HD675-IL1  48.083261  3.077584  364.861568        1900  16600  2.675259
#
# 3                   CCL5       ICAM1    SERPINE1     DEFB1
# Analyte:
# AL-HD615-IL1     5.95097  114.818614  157.091342  4.907788
# AL-HD665-IL1   17.269921  383.345889   378.11869  7.179134
# AL-HD675-IL1  163.335185  368.082444  432.487775  7.276256
#
# [3 rows x 71 columns]
# 3
# 3              IL4     IL1B      IL1A       IFNG       CSF3     KITLG  \
# Analyte:
# AL-HD615-IL4  5500  2.12132   2.12132  26.086864  22.839549  1.342757
# AL-HD665-IL4  5500  2.12132  2.653387  23.656137  22.839549  1.948267
# AL-HD675-IL4  5500  2.12132   2.12132  28.254954  22.839549  1.473322
#
# 3                 IL17F       IL7       IL16      IL18  ...      TGFB1  \
# Analyte:                                                ...
# AL-HD615-IL4  25.912579  8.066916  13.271306  3.678564  ...  48.083261
# AL-HD665-IL4  25.811742   6.93873  18.177034  3.904087  ...  48.083261
# AL-HD675-IL4  24.054552  7.200225   5.820328  3.391803  ...  48.083261
#
# 3                CCL11       VCAM1        TIMP1   MMP2      MMP9      CCL5  \
# Analyte:
# AL-HD615-IL4   2.12132  357.354307   795.543241  16600  8.443997   2.12132
# AL-HD665-IL4   2.12132   66.558189  1683.318724  16600   2.12132  4.169015
# AL-HD675-IL4  3.578541   93.802798         1900  16600   2.44965  3.389407
#
# 3                  ICAM1    SERPINE1      DEFB1
# Analyte:
# AL-HD615-IL4    85.23625   277.85187   3.951051
# AL-HD665-IL4  122.197678  462.166909  11.877325
# AL-HD675-IL4   59.466941  650.547391    2.12132
#
# [3 rows x 71 columns]
# 4
# 3                         IL4        IL1B      IL1A       IFNG        CSF3  \
# Analyte:
# AL-HD615-IL1+IL4         5500  307.024994  3.917148  38.476441   22.839549
# AL-HD665-IL1+IL4         5500  387.883036  7.745424  48.590166  444.623289
# AL-HD675-IL1+IL4  5019.265472  321.206514  4.565344  38.264092  387.096714
#
# 3                    KITLG      IL17F        IL7       IL16      IL18  ...  \
# Analyte:                                                               ...
# AL-HD615-IL1+IL4  2.618678  29.706778   8.663216  30.972071    5.6635  ...
# AL-HD665-IL1+IL4  3.625692  38.007146  11.517742  41.409328  6.007957  ...
# AL-HD675-IL1+IL4  2.992257  29.703529   9.124147  39.609576   5.02026  ...
#
# 3                     TGFB1    CCL11       VCAM1        TIMP1   MMP2  \
# Analyte:
# AL-HD615-IL1+IL4  48.083261  2.12132  488.974642  1226.358377  16600
# AL-HD665-IL1+IL4  48.083261  2.12132  138.462271         1900  16600
# AL-HD675-IL1+IL4  48.083261  2.12132  1155.67953         1900  16600
#
# 3                     MMP9       CCL5       ICAM1    SERPINE1     DEFB1
# Analyte:
# AL-HD615-IL1+IL4  5.469078   4.833154  110.573735  157.399792  4.343915
# AL-HD665-IL1+IL4   2.12132  22.847101  369.759991  308.684077  6.888106
# AL-HD675-IL1+IL4   2.12132  96.263076  222.295362   424.43717  5.234827
#
# [3 rows x 71 columns]
# 5
# 3                          IL4        IL1B      IL1A       IFNG        CSF3  \
# Analyte:
# AL-HD615-IL1+IL10    26.330058   259.01308   2.41846  12.330439  137.901803
# AL-HD665-IL1+IL10    43.859717  355.274096  3.072196   29.75398  438.404543
# AL-HD675-IL1+IL10  1814.452568  210.248526  2.547812   23.80388  279.828826
#
# 3                     KITLG      IL17F       IL7       IL16      IL18  ...  \
# Analyte:                                                               ...
# AL-HD615-IL1+IL10  1.315865  16.263456  4.509176  25.453421  2.442988  ...
# AL-HD665-IL1+IL10  2.771022  26.000169  7.070664  37.126179  4.782072  ...
# AL-HD675-IL1+IL10  1.903229  21.914514  6.111637  30.500823   3.42862  ...
#
# 3                      TGFB1     CCL11       VCAM1       TIMP1   MMP2  \
# Analyte:
# AL-HD615-IL1+IL10  48.083261   2.12132  136.453548  821.631732  16600
# AL-HD665-IL1+IL10  48.083261  2.897013   31.156365        1900  16600
# AL-HD675-IL1+IL10  48.083261   2.12132  323.688583        1900  16600
#
# 3                      MMP9        CCL5       ICAM1    SERPINE1     DEFB1
# Analyte:
# AL-HD615-IL1+IL10  10.69262    5.375977   88.389069  128.466617  4.368767
# AL-HD665-IL1+IL10   2.12132   20.462894  387.710039   408.60976  9.079884
# AL-HD675-IL1+IL10  3.280661  134.485175  288.873905  344.488458  4.600817
#
# [3 rows x 71 columns]

# %% [markdown]
# # Parse healthy file

# %%
secretome_healthy = secretome_healthy.iloc[11:15]

# %%
secretome_healthy.set_index('Analyte:',inplace=True)

# %%
secretome_healthy
# Out:
# 3                   IL4       IL1B     IL1A       IFNG        CSF3     KITLG  \
# Analyte:
# Analyte:            IL4       IL1b     IL1A       IFNG       G-CSF       SCF
# Ctrl          16.334167    2.12132  2.12132   7.212489   25.998347  0.787417
# 10ng/ml IL4  444.903566    2.12132  2.12132  14.288538   22.839549   1.32677
# 1ng/ml IL1    37.210467  172.42016  2.12132  16.369323  152.499418  3.785343
#
# 3                IL17F       IL7      IL16      IL18  ...      TGFB1    CCL11  \
# Analyte:                                              ...
# Analyte:         IL17F       IL7      IL16      IL18  ...     TGF-b1  Eotaxin
# Ctrl         16.263456   2.12132   2.12132  2.483727  ...  75.964071  2.12132
# 10ng/ml IL4  16.263456  2.642344   2.12132  1.450148  ...  65.699719  2.12132
# 1ng/ml IL1   16.263456  3.057097  32.45344  4.463582  ...  55.332347  2.12132
#
# 3                 VCAM1        TIMP1         MMP2       MMP9       CCL5  \
# Analyte:
# Analyte:          VCAM1        TIMP1         MMP2       MMP9     RANTES
# Ctrl         183.742592  2043.327402  3172.412026   2.909747   5.783797
# 10ng/ml IL4  373.871634  2286.971441  3460.932579    3.32896   5.695639
# 1ng/ml IL1   477.833523    2215.3811  3060.108216  11.995282  22.402134
#
# 3                 ICAM1     SERPINE1     DEFB1
# Analyte:
# Analyte:          ICAM1        PAI-1     DEFB1
# Ctrl          36.499868  3415.248219  9.410854
# 10ng/ml IL4   45.048326   3446.90443  8.894347
# 1ng/ml IL1   328.575589  1563.582466  9.315541
#
# [4 rows x 73 columns]

# %%
experiments = ['Ctrl',"IL4","IL1"]

for i,exp in enumerate(experiments):
    df = secretome_healthy[secretome_healthy.index.str.contains(exp)]
    display(df.head())
    secretome_proteins = df.columns.tolist()
    means = [df[col].mean() for col in df.columns.tolist()]
    scaled_means = minmax_scale_list(means)
    
    # Make a dictionary of cytokynes and values
    dictionary_of_means = dict(zip(df.columns.tolist(),scaled_means))
    
    # Force manually depending on the experiment
    if i == 1:
        dictionary_of_means['IL4'] = 1
    elif i == 2:
        dictionary_of_means['IL1'] = 1
    
    for node in all_nodes:
        if node not in secretome_proteins:
            dictionary_of_means[node] = 0

    # Write the files
    with open('../inputs/secretome/healthy_'+exp+'_nodes.txt','w') as f:
        for gene,score in dictionary_of_means.items():
            f.write(gene + ' ' + str(score) + ' ' + '\n')
# Out:
# 3               IL4     IL1B     IL1A      IFNG       CSF3     KITLG  \
# Analyte:
# Ctrl      16.334167  2.12132  2.12132  7.212489  25.998347  0.787417
#
# 3             IL17F      IL7     IL16      IL18  ...      TGFB1    CCL11  \
# Analyte:                                         ...
# Ctrl      16.263456  2.12132  2.12132  2.483727  ...  75.964071  2.12132
#
# 3              VCAM1        TIMP1         MMP2      MMP9      CCL5      ICAM1  \
# Analyte:
# Ctrl      183.742592  2043.327402  3172.412026  2.909747  5.783797  36.499868
#
# 3            SERPINE1     DEFB1
# Analyte:
# Ctrl      3415.248219  9.410854
#
# [1 rows x 73 columns]
# 3                   IL4     IL1B     IL1A       IFNG       CSF3    KITLG  \
# Analyte:
# 10ng/ml IL4  444.903566  2.12132  2.12132  14.288538  22.839549  1.32677
#
# 3                IL17F       IL7     IL16      IL18  ...      TGFB1    CCL11  \
# Analyte:                                             ...
# 10ng/ml IL4  16.263456  2.642344  2.12132  1.450148  ...  65.699719  2.12132
#
# 3                 VCAM1        TIMP1         MMP2     MMP9      CCL5  \
# Analyte:
# 10ng/ml IL4  373.871634  2286.971441  3460.932579  3.32896  5.695639
#
# 3                ICAM1    SERPINE1     DEFB1
# Analyte:
# 10ng/ml IL4  45.048326  3446.90443  8.894347
#
# [1 rows x 73 columns]
# 3                 IL4       IL1B     IL1A       IFNG        CSF3     KITLG  \
# Analyte:
# 1ng/ml IL1  37.210467  172.42016  2.12132  16.369323  152.499418  3.785343
#
# 3               IL17F       IL7      IL16      IL18  ...      TGFB1    CCL11  \
# Analyte:                                             ...
# 1ng/ml IL1  16.263456  3.057097  32.45344  4.463582  ...  55.332347  2.12132
#
# 3                VCAM1      TIMP1         MMP2       MMP9       CCL5  \
# Analyte:
# 1ng/ml IL1  477.833523  2215.3811  3060.108216  11.995282  22.402134
#
# 3                ICAM1     SERPINE1     DEFB1
# Analyte:
# 1ng/ml IL1  328.575589  1563.582466  9.315541
#
# [1 rows x 73 columns]

# %% [markdown]
# # Run Guild

# %%
ls ../guild/
# Out:
# README.md*  data/  doc/  guild_mac*  guild_x64*  src/

# %%
os.listdir('../inputs/secretome/')
# Out:
# ['degenerated_-IL10_nodes.txt',
#  'degenerated_IL1\\+IL10_nodes.txt',
#  'degenerated_IL1\\+IL4_nodes.txt',
#  'healthy_Ctrl_nodes.txt',
#  'healthy_IL1_nodes.txt',
#  'healthy_IL4_nodes.txt']

# %%
import subprocess
import os
interactome_path = '../inputs/'
nodes_path = '../inputs/secretome/'
output_path = '../outputs/secretome/'


for file in os.listdir('../inputs/secretome/'):
    exp_name = file.replace('_nodes.txt','')
    # subprocess.run(['bash','../guild/guild_x64','-s','s','-n',nodes_path+file,'-e',interactome_path+'interactome.sif','-o',output_path+exp_name+'_out.txt'],cwd='../guild/',env={'PATH': '/usr/local/bin:/usr/bin:/bin'})
    os.system('chmod 777 ../inputs/secretome/')
    os.system(f'../guild/guild_x64 -s s -n {nodes_path+file} -e {interactome_path}subnet_enriched.sif -o {output_path+exp_name}_output.txt -i 3 -r 2')
# Out:
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/.ipynb_checkpoints, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/.ipynb_checkpoints_output.txt
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/degenerated_-IL10_nodes.txt, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/degenerated_-IL10_output.txt
# terminate called after throwing an instance of 'std::out_of_range'
#   what():  Unable to find key in unordered_map.
# Aborted
# Time: 4874862 (4.87486s)
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/degenerated_-IL1_nodes.txt, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/degenerated_-IL1_output.txt
# Time: 4421808 (4.42181s)
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/degenerated_-IL4_nodes.txt, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/degenerated_-IL4_output.txt
# Time: 4215509 (4.21551s)
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/degenerated_IL1+IL10_nodes.txt, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/degenerated_IL1+IL10_output.txt
# Time: 4444445 (4.44444s)
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/degenerated_IL1+IL4_nodes.txt, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/degenerated_IL1+IL4_output.txt
# Time: 4486940 (4.48694s)
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/degenerated_No_Treat_nodes.txt, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/degenerated_No_Treat_output.txt
# Time: 4726020 (4.72602s)
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/healthy_Ctrl_nodes.txt, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/healthy_Ctrl_output.txt
# Time: 4729935 (4.72994s)
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/healthy_IL1_nodes.txt, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/healthy_IL1_output.txt
# Time: 4682773 (4.68277s)
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/healthy_IL4_nodes.txt, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/healthy_IL4_output.txt
# Time: 4755327 (4.75533s)
# Arguments: scoring type s, nRepetition 2, nIteration 3, nodeFile ../inputs/secretome/Untitled.ipynb, edgeFile ../inputs/subnet_enriched.sif, outputFile ../outputs/secretome/Untitled.ipynb_output.txt
# terminate called after throwing an instance of 'std::out_of_range'
#   what():  Unable to find key in unordered_map.
# Aborted

# %% [markdown]
# # RUN DIPPER YOUNG AND OLD

# %%
# Load the data and parse the interactome
interactome = pd.read_csv('../data/HIPPIE-current.mitab.txt',sep='\t',low_memory=False)
interactome = interactome[interactome.columns[:2]]
interactome[interactome.columns[0]] = interactome[interactome.columns[0]].apply(lambda x: x.replace('entrez gene:',''))
interactome[interactome.columns[1]] = interactome[interactome.columns[1]].apply(lambda x: x.replace('entrez gene:',''))
interactome = interactome[~interactome['ID Interactor A'].str.contains('-')]
interactome = interactome[~interactome['ID Interactor B'].str.contains('-')]
interactome = interactome.astype(int)
interactome['ID_A_symbol'] = gp.geneId_mapping(interactome['ID Interactor A'].tolist(),'entrez','symbol')
interactome['ID_B_symbol'] = gp.geneId_mapping(interactome['ID Interactor B'].tolist(),'entrez','symbol')
interactome.dropna(inplace=True)
interactome_net = nx.from_pandas_edgelist(interactome[['ID_A_symbol','ID_B_symbol']],source='ID_A_symbol',target='ID_B_symbol')
largest_cc = max(nx.connected_components(interactome_net), key=len)
interactome_cc = nx.subgraph(interactome_net,largest_cc)
interactome_pandas = nx.to_pandas_edgelist(interactome_cc)
interactome_pandas.insert(1,'score',1)
il4_edges = interactome[(interactome.ID_A_symbol == 'IL4') | (interactome.ID_B_symbol == 'IL4')].iloc[:,2:].values
il10_edges = interactome[(interactome.ID_A_symbol == 'IL10') | (interactome.ID_B_symbol == 'IL10')].iloc[:,2:].values
il10_genes= set([item for sublist in il10_edges for item in sublist if item != 'IL10'])
il4_genes= set([item for sublist in il4_edges for item in sublist if item != 'IL4'])
genes_interactome = set(interactome_pandas['source'].tolist() + interactome_pandas['target'].tolist())

# %%
Dipper = pd.read_csv('../data/dipper_protein_expression.csv')
Dipper=Dipper.iloc[:,2:]
Dipper.columns=[x.replace(".", "_") for x in Dipper.columns]
columnyoungfilter=[column for column in Dipper.columns.tolist() if ('young_NP' in column) ]
columnoldfilter=[column for column in Dipper.columns.tolist() if ('old_NP' in column) ]

columnyoungfilter=columnyoungfilter+list(Dipper.columns[:3])
columnoldfilter = columnoldfilter+list(Dipper.columns[:3])

dipper_young = Dipper[columnyoungfilter]
dipper_old = Dipper[columnoldfilter]
dipper_young = dipper_young.dropna(subset=['L3_4_young_NP','L4_5_young_NP','L5_S1_young_NP'],how='all')
dipper_old = dipper_old.dropna(subset=['L3_4_old_NP','L4_5_old_NP','L5_S1_old_NP'],how='all')

# %% [markdown]
# # Here we will filter the interactome:
#
# We need to obtain 4 interactomes with All the genes that interact with il4 and il10 and that are expressed in the disc, if there is no expression of these we will force the genes to be there

# %%
gene_symbol_list_seeds=['IL6', 'IL6ST','IL16', 'IL1B', 'IL17D', 'IL18', 'IL20', 'TNF', 'LIF', 'OSM', 'CCL2', 'CCL3', 'CCL5', 'CCL7', 'CXCL1', 'CXCL2', 'CXCL3', 'CXCL8', 'CX3CL1', 'IGF1', 'GDF5', 'TGFB1', 'GDF6', 'PMP2', 'VEGFA']

# %%
# get the genes of dipper young and old
genes_dipper_young = dipper_young['Gene_names'].tolist()
genes_dipper_old = dipper_old['Gene_names'].tolist()

# The seeds have been found in the lab to be expressed in the disc so we will force their presence in the final interactomes
missing_seeds_young = [gene for gene in gene_symbol_list_seeds if gene not in genes_dipper_young]
missing_seeds_old = [gene for gene in gene_symbol_list_seeds if gene not in genes_dipper_old]
genes_interactome_expressed_young = dipper_young.Gene_names.tolist() + missing_seeds_young
genes_interactome_expressed_old = dipper_old.Gene_names.tolist() + missing_seeds_old

# We will force also in the interactome to be present the genes that interact with Il4 and IL10 that are expressed 
filtered_connections_il10 = [edge for edge in il10_edges if ('IGHG1' in edge) or ('A2M' in edge)]
filtered_connections_il4 = [edge for edge in il4_edges if 'A2M' in edge]
filtered_connections_il10_df = pd.DataFrame([[a,1,b] for [a,b] in filtered_connections_il10],columns=['source','sore','target'])
filtered_connections_il4_df = pd.DataFrame([[a,1,b] for [a,b] in filtered_connections_il4],columns=['source','sore','target'])


# Create the 2 filtered interactomes
interactome_young = interactome_pandas[(interactome_pandas.source.isin(genes_interactome_expressed_young)) | (interactome_pandas.target.isin(genes_interactome_expressed_young))]
interactome_old = interactome_pandas[(interactome_pandas.source.isin(genes_interactome_expressed_old)) | (interactome_pandas.target.isin(genes_interactome_expressed_old))]
interactome_young_IL4 = pd.concat([interactome_young,filtered_connections_il4_df],ignore_index=True)
interactome_old_IL4 = pd.concat([interactome_old,filtered_connections_il4_df],ignore_index=True)
interactome_young_IL10 = pd.concat([interactome_young,filtered_connections_il10_df],ignore_index=True)
interactome_old_IL10 = pd.concat([interactome_young,filtered_connections_il10_df],ignore_index=True)

# Make sure the filtered young and old interactomes are connected
interactome_young_net = nx.from_pandas_edgelist(interactome_young)
interactome_old_net = nx.from_pandas_edgelist(interactome_old)
interactome_young_net_IL4 = nx.from_pandas_edgelist(interactome_young_IL4)
interactome_old_net_IL4 = nx.from_pandas_edgelist(interactome_old_IL4)
interactome_young_net_IL10 = nx.from_pandas_edgelist(interactome_young_IL10)
interactome_old_net_IL10 = nx.from_pandas_edgelist(interactome_old_IL10)

# Create seeds files
seeds_young = list(zip(genes_interactome_expressed_young, [1 if gene in gene_symbol_list_seeds else 0 for gene in genes_interactome_expressed_young]))
# write the inputs
with open(f'../inputs/Dipper/seeds_young.txt','w') as f:
    for s in seeds_young:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')

seeds_young_IL4 = list(zip(genes_interactome_expressed_young + ['IL4'], [1 if gene in gene_symbol_list_seeds +['IL4'] else 0 for gene in genes_interactome_expressed_young + ['IL4']]))
# write the inputs
with open(f'../inputs/Dipper/seeds_young_IL4.txt','w') as f:
    for s in seeds_young_IL4:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')
        
seeds_young_IL10 = list(zip(genes_interactome_expressed_young + ['IL10'], [1 if gene in gene_symbol_list_seeds +['IL10'] else 0 for gene in genes_interactome_expressed_young + ['IL10']]))
# write the inputs
with open(f'../inputs/Dipper/seeds_young_IL10.txt','w') as f:
    for s in seeds_young_IL10:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')

seeds_old= list(zip(genes_interactome_expressed_old, [1 if gene in gene_symbol_list_seeds else 0 for gene in genes_interactome_expressed_old]))
# write the inputs
with open(f'../inputs/Dipper/seeds_old.txt','w') as f:
    for s in seeds_old:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')

seeds_old_IL4 = list(zip(genes_interactome_expressed_old + ['IL4'], [1 if gene in gene_symbol_list_seeds +['IL4'] else 0 for gene in genes_interactome_expressed_old + ['IL4']]))
# write the inputs
with open(f'../inputs/Dipper/seeds_old_IL4.txt','w') as f:
    for s in seeds_old_IL4:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')
        
seeds_old_IL10 = list(zip(genes_interactome_expressed_old + ['IL10'], [1 if gene in gene_symbol_list_seeds +['IL10'] else 0 for gene in genes_interactome_expressed_old + ['IL10']]))
# write the inputs
with open(f'../inputs/Dipper/seeds_old_IL10.txt','w') as f:
    for s in seeds_old_IL10:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')

# %% [markdown]
# # RUN THE EXPERIMENTS IT WILL BE 6 EXPERIMENTS AS FOLLOWS:
#  - YOUNG ALLSEEDS
#  - YOUNG ALLSEEDS + IL4
#  - YOUNG ALLSEEDS + IL10
#  - OLD ALLSEEDS
#  - OLD ASLLSEEDS + IL4
#  - OLD ALLSEEDS + IL10

# %%
for i,exp in enumerate(experiments):
    # The interactome have to be composed from only the genes experessed either in old and young dipper
    if i == 0:
        print(f"Performing experiment {exp}")

        # running guild
        os.system(f'../guild/guild_x64 -s s -n {f'../inputs/{exp}_seeds.txt'} -e ../inputs/interactome_young.txt -o ../outputs/{exp}_Dipper_out.txt')
        
        
        
    elif i == 1:
        print(f"Performing experiment {exp}")
        # make the seeds file
        seeds = list(zip(genes_interactome_expressed_old, [1 if gene in gene_symbol_list_seeds else 0 for gene in genes_interactome_expressed_old]))
        # write the inputs
        with open(f'../inputs/{exp}_seeds.txt','w') as f:
            for s in seeds:
                f.write(str(s[0]) + '\t' + s[1] + '\n')
        # run guild
        os.system(f'../guild/guild_x64 -s s -n {f'../inputs/{exp}_seeds.txt'} -e ../inputs/interactome_old.txt -o ../outputs/{exp}_Dipper_out.txt')
        
    elif i == 2:
        print(f"Performing experiment {exp}")
        # Append the connection of IL4 
        
        
        seeds = list(zip(genes_interactome_expressed_young_IL4, [1 if gene in gene_symbol_list_seeds_IL4 else 0 for gene in genes_interactome_expressed_young_IL4]))

        # make the seeds file
        seeds = list(zip(genes_interactome_expressed_old, [1 if gene in gene_symbol_list_seeds else 0 for gene in genes_interactome_expressed_old]))
        # write the inputs
        with open(f'../inputs/{exp}_seeds.txt','w') as f:
            for s in seeds:
                f.write(str(s[0]) + '\t' + s[1] + '\n')
        # run guild
        os.system(f'../guild/guild_x64 -s s -n {f'../inputs/{exp}_seeds.txt'} -e ../inputs/interactome_old.sif -o ../outputs/{exp}_Dipper_out.txt')
# Out:
# (129094, 3)
# (111285, 3)

# %%
il10_edges
# Out:
# array([['IL10', 'IL10'],
#        ['IL10', 'IL10RB'],
#        ['IL10RA', 'IL10'],
#        ['IL10', 'A2M'],
#        ['IGHG1', 'IL10'],
#        ['KRTAP10-8', 'IL10'],
#        ['GLRX3', 'IL10'],
#        ['KRTAP1-3', 'IL10'],
#        ['YY1', 'IL10'],
#        ['IL10', 'CCNA2'],
#        ['IL10', 'KRTAP4-1'],
#        ['IL10', 'CRYGD'],
#        ['IL10', 'LRP2'],
#        ['IL10', 'MTMR3'],
#        ['IL10', 'VGF'],
#        ['IL10', 'MTMR4'],
#        ['IL10', 'NOTCH2NLA']], dtype=object)

# %%
interactome_old_IL10.tail()
# Out:
#           source  score  target  sore
# 139829  KRTAP6-1    1.0   ITIH6   NaN
# 139830     ITIH6    1.0  SMIM29   NaN
# 139831     OR2A4    1.0   IGLC6   NaN
# 139832      IL10    NaN     A2M   1.0
# 139833     IGHG1    NaN    IL10   1.0

# %%
[gene for gene in gene_symbol_list_seeds if gene not in nodes_young]
# Out:
# ['CCL4']

# %%
'CCL4' in genes_interactome_expressed_young
# Out:
# True

# %%
[gene for gene in gene_symbol_list_seeds if gene not in nodes_old]
# Out:
# ['CCL4']

# %%
# Load the data and parse the interactome
interactome = pd.read_csv('../data/HIPPIE-current.mitab.txt',sep='\t',low_memory=False)
interactome = interactome[interactome.columns[:2]]
interactome[interactome.columns[0]] = interactome[interactome.columns[0]].apply(lambda x: x.replace('entrez gene:',''))
interactome[interactome.columns[1]] = interactome[interactome.columns[1]].apply(lambda x: x.replace('entrez gene:',''))
interactome = interactome[~interactome['ID Interactor A'].str.contains('-')]
interactome = interactome[~interactome['ID Interactor B'].str.contains('-')]
interactome = interactome.astype(int)
interactome['ID_A_symbol'] = gp.geneId_mapping(interactome['ID Interactor A'].tolist(),'entrez','symbol')
interactome['ID_B_symbol'] = gp.geneId_mapping(interactome['ID Interactor B'].tolist(),'entrez','symbol')
interactome.dropna(inplace=True)
interactome_net = nx.from_pandas_edgelist(interactome[['ID_A_symbol','ID_B_symbol']],source='ID_A_symbol',target='ID_B_symbol')
largest_cc = max(nx.connected_components(interactome_net), key=len)
interactome_cc = nx.subgraph(interactome_net,largest_cc)
interactome_pandas = nx.to_pandas_edgelist(interactome_cc)
interactome_pandas.insert(1,'score',1)
il4_edges = interactome[(interactome.ID_A_symbol == 'IL4') | (interactome.ID_B_symbol == 'IL4')].iloc[:,2:].values
il10_edges = interactome[(interactome.ID_A_symbol == 'IL10') | (interactome.ID_B_symbol == 'IL10')].iloc[:,2:].values


Dipper = pd.read_csv('../data/dipper_protein_expression.csv')
Dipper=Dipper.iloc[:,2:]
Dipper.columns=[x.replace(".", "_") for x in Dipper.columns]
columnyoungfilter=[column for column in Dipper.columns.tolist() if ('young_NP' in column) ]
columnoldfilter=[column for column in Dipper.columns.tolist() if ('old_NP' in column) ]

columnyoungfilter=columnyoungfilter+list(Dipper.columns[:3])
columnoldfilter = columnoldfilter+list(Dipper.columns[:3])

dipper_young = Dipper[columnyoungfilter]
dipper_old = Dipper[columnoldfilter]
dipper_young = dipper_young.dropna(subset=['L3_4_young_NP','L4_5_young_NP','L5_S1_young_NP'],how='all')
dipper_old = dipper_old.dropna(subset=['L3_4_old_NP','L4_5_old_NP','L5_S1_old_NP'],how='all')

gene_symbol_list_seeds=['IL6', 'IL6ST','IL16', 'IL1B', 'IL17D', 'IL18', 'IL20', 'TNF', 'LIF', 'OSM', 'CCL2', 'CCL3', 'CCL5', 'CCL7', 'CXCL1', 'CXCL2', 'CXCL3', 'CXCL8', 'CX3CL1', 'IGF1', 'GDF5', 'TGFB1', 'GDF6', 'PMP2', 'VEGFA']
#CCL4 was removed due to the absence of data in the interactome

# get the genes of dipper young and old
genes_dipper_young = dipper_young['Gene_names'].tolist()
genes_dipper_old = dipper_old['Gene_names'].tolist()

# The seeds have been found in the lab to be expressed in the disc so we will force their presence in the final interactomes
missing_seeds_young = [gene for gene in gene_symbol_list_seeds if gene not in genes_dipper_young]
missing_seeds_old = [gene for gene in gene_symbol_list_seeds if gene not in genes_dipper_old]
genes_interactome_expressed_young = dipper_young.Gene_names.tolist() + missing_seeds_young
genes_interactome_expressed_old = dipper_old.Gene_names.tolist() + missing_seeds_old
genes_interactome_expressed_young = sum([a.split(';') for a in genes_interactome_expressed_young],[])
genes_interactome_expressed_old = sum([a.split(';') for a in genes_interactome_expressed_old],[])

# We will force also in the interactome to be present the genes that interact with Il4 and IL10 that are expressed 
filtered_connections_il10 = [edge for edge in il10_edges if ('IGHG1' in edge) or ('A2M' in edge)]
filtered_connections_il4 = [edge for edge in il4_edges if 'A2M' in edge]
filtered_connections_il10_df = pd.DataFrame([[a,1,b] for [a,b] in filtered_connections_il10],columns=['source','score','target'])
filtered_connections_il4_df = pd.DataFrame([[a,1,b] for [a,b] in filtered_connections_il4],columns=['source','score','target'])

# Create the filtered interactomes
interactome_young = interactome_pandas[(interactome_pandas.source.isin(genes_interactome_expressed_young)) | (interactome_pandas.target.isin(genes_interactome_expressed_young))]
interactome_old = interactome_pandas[(interactome_pandas.source.isin(genes_interactome_expressed_old)) | (interactome_pandas.target.isin(genes_interactome_expressed_old))]
interactome_young_IL4 = pd.concat([interactome_young,filtered_connections_il4_df])
interactome_old_IL4 = pd.concat([interactome_old,filtered_connections_il4_df])
interactome_young_IL10 = pd.concat([interactome_young,filtered_connections_il10_df])
interactome_old_IL10 = pd.concat([interactome_old,filtered_connections_il10_df])


# Make sure the filtered young and old interactomes are connected
interactome_young_net = nx.from_pandas_edgelist(interactome_young)
interactome_old_net = nx.from_pandas_edgelist(interactome_old)
interactome_young_net_IL4 = nx.from_pandas_edgelist(interactome_young_IL4)
interactome_old_net_IL4 = nx.from_pandas_edgelist(interactome_old_IL4)
interactome_young_net_IL10 = nx.from_pandas_edgelist(interactome_young_IL10)
interactome_old_net_IL10 = nx.from_pandas_edgelist(interactome_old_IL10)

# Create node file
nodes_young = list(set(interactome_young.source.tolist() + interactome_young.target.tolist()))
nodes_old = list(set(interactome_old.source.tolist() + interactome_old.target.tolist()))
nodes_old_IL4 = list(set(interactome_old_IL4.source.tolist() + interactome_old_IL4.target.tolist()))
nodes_old_IL10 = list(set(interactome_old_IL10.source.tolist() + interactome_old_IL10.target.tolist()))
nodes_young_IL4 = list(set(interactome_young_IL4.source.tolist() + interactome_young_IL4.target.tolist()))
nodes_young_IL10 = list(set(interactome_young_IL10.source.tolist() + interactome_young_IL10.target.tolist()))

# Save the interactomes
def get_var_name(variable):
    for name, value in globals().items():
        if value is variable:
            return name

#check if the interactomes are all connected
interactomes = [interactome_old_net_IL10 ,interactome_young_net_IL10,interactome_old_net_IL4,interactome_young_net_IL4,interactome_old_net,interactome_young_net]

for inte in interactomes:
    int_name = get_var_name(inte)
    largest_cc = max(nx.connected_components(inte), key=len)
    if len(largest_cc)==len(inte.nodes()):
        pass
    else:
        print(f"The there is discrepancies between lcc and interactome for interactome {int_name}")


# Save the interactomes
interactomes = [interactome_old_IL10 ,interactome_young_IL10, interactome_old_IL4,interactome_young_IL4,interactome_old,interactome_young]
for inte in interactomes:
    inte_name =  get_var_name(inte)
    inte.to_csv(f'../inputs/Dipper/{inte_name}.txt',index=False,header=False,sep = '\t')

# %%
# Create seeds files
seeds_young = list(zip(nodes_young, [1 if gene in gene_symbol_list_seeds else 0 for gene in nodes_young]))
# write the inputs
with open(f'../inputs/Dipper/seeds_young.txt','w') as f:
    for s in seeds_young:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')

seeds_young_IL4 = list(zip(nodes_young_IL4, [1 if gene in gene_symbol_list_seeds + ['IL4'] else 0 for gene in nodes_young_IL4]))
# write the inputs
with open(f'../inputs/Dipper/seeds_young_IL4.txt','w') as f:
    for s in seeds_young_IL4:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')
        
seeds_young_IL10 = list(zip(nodes_young_IL10, [1 if gene in gene_symbol_list_seeds +['IL10'] else 0 for gene in nodes_young10]))
# write the inputs
with open(f'../inputs/Dipper/seeds_young_IL10.txt','w') as f:
    for s in seeds_young_IL10:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')

seeds_old= list(zip(nodes_old, [1 if gene in gene_symbol_list_seeds else 0 for gene in nodes_old]))
# write the inputs
with open(f'../inputs/Dipper/seeds_old.txt','w') as f:
    for s in seeds_old:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')

seeds_old_IL4 = list(zip(nodes_old + ['IL4'], [1 if gene in gene_symbol_list_seeds +['IL4'] else 0 for gene in nodes_old + ['IL4']]))
# write the inputs
with open(f'../inputs/Dipper/seeds_old_IL4.txt','w') as f:
    for s in seeds_old_IL4:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')
        
seeds_old_IL10 = list(zip(nodes_old + ['IL10'], [1 if gene in gene_symbol_list_seeds +['IL10'] else 0 for gene in nodes_old + ['IL10']]))
# write the inputs
with open(f'../inputs/Dipper/seeds_old_IL10.txt','w') as f:
    for s in seeds_old_IL10:
        f.write(str(s[0]) + '\t' + str(s[1]) + '\n')
# Out:
# The there is discrepancies between lcc and interactome for interactome variable
# The there is discrepancies between lcc and interactome for interactome variable
# The there is discrepancies between lcc and interactome for interactome variable
# The there is discrepancies between lcc and interactome for interactome variable
# The there is discrepancies between lcc and interactome for interactome variable
# The there is discrepancies between lcc and interactome for interactome variable

# %%
interactome_young_genes = list(set(interactome_young.source.tolist() + interactome_young.target.tolist()))
interactome_old_IL10_genes = set(interactome_old_IL10.source.tolist() + interactome_old_IL10.target.tolist())

# %%
all([gene in nodes_young for gene in interactome_young_genes])
all([gene in nodes_old_IL10 for gene in interactome_old_IL10_genes ])
# Out:
# True

# %%
all([gene in interactome_old_IL10_genes for gene in nodes_old + ['IL10'] ])
# Out:
# False

# %%
all([gene in nodes_old + ['IL10'] for gene in interactome_old_IL10_genes])
# Out:
# False

# %%
interactome_young_IL4
# Out:
#           source  score  target
# 5        ALDH1A1      1   NEDD8
# 44         ITGA7      1   ITGB1
# 45         ITGA7      1  COL6A1
# 46         ITGA7      1   LAMC1
# 49         ITGA7      1  COL1A2
# ...          ...    ...     ...
# 775604      EVX2      1   ITIH6
# 775694  KRTAP6-1      1   ITIH6
# 775791     ITIH6      1  SMIM29
# 775810     OR2A4      1   IGLC6
# 0            A2M      1     IL4
#
# [139833 rows x 3 columns]

# %%
interactome_young
# Out:
#           source  score  target
# 5        ALDH1A1      1   NEDD8
# 44         ITGA7      1   ITGB1
# 45         ITGA7      1  COL6A1
# 46         ITGA7      1   LAMC1
# 49         ITGA7      1  COL1A2
# ...          ...    ...     ...
# 775580      AQP6      1  CGREF1
# 775604      EVX2      1   ITIH6
# 775694  KRTAP6-1      1   ITIH6
# 775791     ITIH6      1  SMIM29
# 775810     OR2A4      1   IGLC6
#
# [139832 rows x 3 columns]

# %%
with open('../outputs/Dipper/All_old_Dipper_out.txt','r') as f:
    res = f.readlines()
    
res
# Out:
# ['LHX1\t0\n',
#  'ATG4B\t0\n',
#  'UGT1A10\t0\n',
#  'CELA3A\t0\n',
#  'OXA1L\t0\n',
#  'PTMA\t0\n',
#  'FAM222B\t0\n',
#  'GUCY1A1\t0\n',
#  'VAMP7\t0\n',
#  'DHX37\t0\n',
#  'CDH9\t0\n',
#  'SLC20A2\t0\n',
#  'IGLL5\t0\n',
#  'SATB2\t0\n',
#  'GJB2\t0\n',
#  'GAGE4\t0\n',
#  'FGD4\t0\n',
#  'AKIRIN1\t0\n',
#  'RBBP6\t0\n',
#  'PPP2R3A\t0\n',
#  'LPIN1\t0\n',
#  'KRTAP13-3\t0\n',
#  'NDUFB8\t0\n',
#  'DUSP1\t0\n',
#  'OGDH\t0\n',
#  'RECQL\t0\n',
#  'CDH17\t0\n',
#  'NSUN5P1\t0\n',
#  'ASB14\t0\n',
#  'DSE\t0\n',
#  'MITF\t0\n',
#  'SPG11\t0\n',
#  'AKR7A3\t0\n',
#  'NGRN\t0\n',
#  'ZCRB1\t0\n',
#  'TRIP12\t0\n',
#  'FZD4\t0\n',
#  'ANG\t0\n',
#  'AGER\t0\n',
#  'TGOLN2\t0\n',
#  'ST3GAL4\t0\n',
#  'IL36RN\t0\n',
#  'HPS3\t0\n',
#  'POLR2J\t0\n',
#  'RAB19\t0\n',
#  'IRAG2\t0\n',
#  'USP19\t0\n',
#  'ZCCHC3\t0\n',
#  'PTPN3\t0\n',
#  'HIVEP3\t0\n',
#  'PTH\t0\n',
#  'ZNF584\t0\n',
#  'CDKL3\t0\n',
#  'GLB1L\t0\n',
#  'IQCF2\t0\n',
#  'UBR3\t0\n',
#  'CSF1R\t0\n',
#  'TRIM35\t0\n',
#  'HPSE2\t0\n',
#  'S1PR5\t0\n',
#  'PSMC6\t0\n',
#  'CLDN1\t0\n',
#  'AJUBA\t0\n',
#  'AGBL5\t0\n',
#  'ACSL1\t0\n',
#  'DZIP3\t0\n',
#  'PRPF4\t0\n',
#  'CALCA\t0\n',
#  'OPHN1\t0\n',
#  'FCAR\t0\n',
#  'CENPM\t0\n',
#  'USP25\t0\n',
#  'TMEM106A\t0\n',
#  'UFD1\t0\n',
#  'NXF5\t0\n',
#  'CDH15\t0\n',
#  'GABRR2\t0\n',
#  'PCARE\t0\n',
#  'CORO7\t0\n',
#  'ESRP2\t0\n',
#  'CSTB\t0\n',
#  'CAMK1G\t0\n',
#  'PRKAA2\t0\n',
#  'TRIO\t0\n',
#  'FAM25G\t0\n',
#  'CHST13\t0\n',
#  'CDK13\t0\n',
#  'TRNT1\t0\n',
#  'INO80C\t0\n',
#  'SHFL\t0\n',
#  'CLEC4A\t0\n',
#  'HES4\t0\n',
#  'SLC38A3\t0\n',
#  'HMMR\t0\n',
#  'SOX17\t0\n',
#  'CDH12\t0\n',
#  'TCP11L1\t0\n',
#  'TMEM104\t0\n',
#  'URI1\t0\n',
#  'GARRE1\t0\n',
#  'MIR34C\t0\n',
#  'GPBP1L1\t0\n',
#  'CACNA1S\t0\n',
#  'LONRF2\t0\n',
#  'ARFIP2\t0\n',
#  'NUSAP1\t0\n',
#  'EIF5A2\t0\n',
#  'SMC2\t0\n',
#  'CCDC102B\t0\n',
#  'TRIM32\t0\n',
#  'C8orf34\t0\n',
#  'TYSND1\t0\n',
#  'VPS13D\t0\n',
#  'UGT2A3\t0\n',
#  'KCNG1\t0\n',
#  'TUBA8\t0\n',
#  'OR51E2\t0\n',
#  'SLC6A6\t0\n',
#  'GOLGA8A\t0\n',
#  'NALCN\t0\n',
#  'PCOLCE-AS1\t0\n',
#  'PTPMT1\t0\n',
#  'TPRKB\t0\n',
#  'UBFD1\t0\n',
#  'TRDN\t0\n',
#  'PHF1\t0\n',
#  'ATAD1\t0\n',
#  'EPHB3\t0\n',
#  'ZNF532\t0\n',
#  'PPP4R4\t0\n',
#  'HSD3B1\t0\n',
#  'RNLS\t0\n',
#  'BOD1\t0\n',
#  'PSKH2\t0\n',
#  'SYNJ1\t0\n',
#  'PLEKHB1\t0\n',
#  'TSGA10IP\t0\n',
#  'NCBP2\t0\n',
#  'ANKS1A\t0\n',
#  'ERCC1\t0\n',
#  'MIR363\t0\n',
#  'METAP1\t0\n',
#  'LBX1\t0\n',
#  'KIF22\t0\n',
#  'MTO1\t0\n',
#  'ABCD3\t0\n',
#  'CENPJ\t0\n',
#  'PLEKHA3\t0\n',
#  'CHIC1\t0\n',
#  'ROBO2\t0\n',
#  'CABLES1\t0\n',
#  'GUCY2F\t0\n',
#  'DCAF4L1\t0\n',
#  'GNG8\t0\n',
#  'LY96\t0\n',
#  'ABCA17P\t0\n',
#  'GHDC\t0\n',
#  'RBPMS\t0\n',
#  'PSPH\t0\n',
#  'TCEAL5\t0\n',
#  'CD99P1\t0\n',
#  'AIRE\t0\n',
#  'MMP10\t0\n',
#  'CD1E\t0\n',
#  'CPEB4\t0\n',
#  'ALDH7A1\t0\n',
#  'AAMDC\t0\n',
#  'RAMP3\t0\n',
#  'SHOX2\t0\n',
#  'PLD6\t0\n',
#  'DCAF10\t0\n',
#  'GPR89A\t0\n',
#  'HTR3C\t0\n',
#  'SIGLEC6\t0\n',
#  'MTSS1\t0\n',
#  'RPL36\t0\n',
#  'SLC38A10\t0\n',
#  'CAPSL\t0\n',
#  'SYT2\t0\n',
#  'NDUFA2\t0\n',
#  'SPINT1\t0\n',
#  'GPR37L1\t0\n',
#  'NCAN\t0\n',
#  'IDH3A\t0\n',
#  'ZMYM6\t0\n',
#  'CCDC80\t0\n',
#  'ZNF667\t0\n',
#  'CGRRF1\t0\n',
#  'GABRA6\t0\n',
#  'CCDC115\t0\n',
#  'INTU\t0\n',
#  'PTPRC\t0\n',
#  'TRIM31\t0\n',
#  'KCNIP4\t0\n',
#  'NELFE\t0\n',
#  'NRIP1\t0\n',
#  'LYRM2\t0\n',
#  'DUX4\t0\n',
#  'TRAK2\t0\n',
#  'ZNF567\t0\n',
#  'H1-0\t0\n',
#  'DIAPH2\t0\n',
#  'TMEM120B\t0\n',
#  'ITGAM\t0\n',
#  'H3C1\t0\n',
#  'KRT81\t0\n',
#  'MR1\t0\n',
#  'PSMD4\t0\n',
#  'WDR76\t0\n',
#  'CKLF\t0\n',
#  'NEFM\t0\n',
#  'IGKV2D-28\t0\n',
#  'C5orf24\t0\n',
#  'ACSF3\t0\n',
#  'PEDS1\t0\n',
#  'RPL13P12\t0\n',
#  'DISP1\t0\n',
#  'ZFAND2B\t0\n',
#  'AQP2\t0\n',
#  'EEF1G\t0\n',
#  'PAIP2\t0\n',
#  'AQP10\t0\n',
#  'FAM76B\t0\n',
#  'MTHFD1L\t0\n',
#  'MFN2\t0\n',
#  'EPS15L1\t0\n',
#  'FBXW4P1\t0\n',
#  'CCDC137\t0\n',
#  'AAR2\t0\n',
#  'CYB561A3\t0\n',
#  'CLEC4E\t0\n',
#  'NR2F6\t0\n',
#  'VWA5A\t0\n',
#  'SAAL1\t0\n',
#  'HMGCS1\t0\n',
#  'TMOD4\t0\n',
#  'MCM8\t0\n',
#  'GUSB\t0\n',
#  'ILKAP\t0\n',
#  'ARMC12\t0\n',
#  'FOXP1\t0\n',
#  'ZFYVE9\t0\n',
#  'P2RY6\t0\n',
#  'ERVMER34-1\t0\n',
#  'FBXL2\t0\n',
#  'DACH2\t0\n',
#  'TUBD1\t0\n',
#  'SEMA4F\t0\n',
#  'CCR6\t0\n',
#  'XPR1\t0\n',
#  'C4orf47\t0\n',
#  'EIF2AK3\t0\n',
#  'REL\t0\n',
#  'ZYG11B\t0\n',
#  'MYOF\t0\n',
#  'HSPA2\t0\n',
#  'CFAP57\t0\n',
#  'CDH7\t0\n',
#  'RPS26P54\t0\n',
#  'NCOA2\t0\n',
#  'SLC52A3\t0\n',
#  'PVRIG\t0\n',
#  'ATG10\t0\n',
#  'DUSP16\t0\n',
#  'VWCE\t0\n',
#  'CCDC144BP\t0\n',
#  'RNF115\t0\n',
#  'SLC35B2\t0\n',
#  'DNAAF1\t0\n',
#  'FGD5\t0\n',
#  'DPF1\t0\n',
#  'CNOT9\t0\n',
#  'BCL6\t0\n',
#  'RAB14\t0\n',
#  'CMAS\t0\n',
#  'ARID5B\t0\n',
#  'BEST1\t0\n',
#  'BTN3A1\t0\n',
#  'UNC79\t0\n',
#  'HNRNPH3\t0\n',
#  'EIF1B\t0\n',
#  'HDX\t0\n',
#  'NID2\t0\n',
#  'MRPL11\t0\n',
#  'NUDT13\t0\n',
#  'RBMXP1\t0\n',
#  'RALGDS\t0\n',
#  'FAM98C\t0\n',
#  'NUP54\t0\n',
#  'MECOM\t0\n',
#  'DCAF4\t0\n',
#  'MSR1\t0\n',
#  'RRM2\t0\n',
#  'MORC4\t0\n',
#  'ACADVL\t0\n',
#  'MAP2K4\t0\n',
#  'EFNB2\t0\n',
#  'OSTC\t0\n',
#  'NEUROD2\t0\n',
#  'LUM\t0\n',
#  'GALNTL5\t0\n',
#  'ARID3B\t0\n',
#  'PRDM7\t0\n',
#  'ADPGK\t0\n',
#  'TRIM4\t0\n',
#  'TNS2\t0\n',
#  'TRAPPC12\t0\n',
#  'KIR2DS2\t0\n',
#  'SLC40A1\t0\n',
#  'S100A5\t0\n',
#  'AP3S1\t0\n',
#  'KHDC4\t0\n',
#  'CNN2\t0\n',
#  'DDX31\t0\n',
#  'NHLRC1\t0\n',
#  'ANKRD34C\t0\n',
#  'C1orf146\t0\n',
#  'PTPRK\t0\n',
#  'WFDC5\t0\n',
#  'ZFP2\t0\n',
#  'CMIP\t0\n',
#  'PAIP1\t0\n',
#  'PACSIN3\t0\n',
#  'PCDHGA6\t0\n',
#  'INO80\t0\n',
#  'ERLIN1\t0\n',
#  'MPHOSPH6\t0\n',
#  'GRIA1\t0\n',
#  'ZNF138\t0\n',
#  'ECI1\t0\n',
#  'THRB\t0\n',
#  'MRPL17\t0\n',
#  'RTKN\t0\n',
#  'DGKH\t0\n',
#  'EIF3CL\t0\n',
#  'TNN\t0\n',
#  'STK19\t0\n',
#  'OR51F2\t0\n',
#  'FEM1A\t0\n',
#  'DNAAF9\t0\n',
#  'DLD\t0\n',
#  'APAF1\t0\n',
#  'TNKS2\t0\n',
#  'HOXB1\t0\n',
#  'ZNF286A\t0\n',
#  'SHROOM1\t0\n',
#  'MLIP\t0\n',
#  'KNG1\t0\n',
#  'BCL9L\t0\n',
#  'RNF144A\t0\n',
#  'DCTN4\t0\n',
#  'CDK11B\t0\n',
#  'SPP1\t0\n',
#  'PHACTR3\t0\n',
#  'PKN1\t0\n',
#  'TMPRSS11E\t0\n',
#  'ATP2B3\t0\n',
#  'GPR101\t0\n',
#  'IRF1\t0\n',
#  'RNF150\t0\n',
#  'SMARCC2\t0\n',
#  'ZFP62\t0\n',
#  'CAPN5\t0\n',
#  'TMED10\t0\n',
#  'PRSS35\t0\n',
#  'DYM\t0\n',
#  'TRAPPC6B\t0\n',
#  'CHD4\t0\n',
#  'COX20\t0\n',
#  'DYNC2H1\t0\n',
#  'MRPS33\t0\n',
#  'PIH1D2\t0\n',
#  'CHCHD7\t0\n',
#  'OAZ3\t0\n',
#  'ZSCAN4\t0\n',
#  'SREK1\t0\n',
#  'EAPP\t0\n',
#  'FBXO32\t0\n',
#  'C1RL\t0\n',
#  'FAM43B\t0\n',
#  'KLHL15\t0\n',
#  'TFDP3\t0\n',
#  'ASTL\t0\n',
#  'TXNDC9\t0\n',
#  'CDH11\t0\n',
#  'NOX4\t0\n',
#  'BRINP2\t0\n',
#  'PGAM4\t0\n',
#  'ANKRD40\t0\n',
#  'MEX3A\t0\n',
#  'GAD2\t0\n',
#  'BEGAIN\t0\n',
#  'RSBN1L\t0\n',
#  'PRKD3\t0\n',
#  'WNK1\t0\n',
#  'AFDN\t0\n',
#  'IMP3\t0\n',
#  'ANKRD29\t0\n',
#  'LMNTD2\t0\n',
#  'ZSCAN5A\t0\n',
#  'CASP8AP2\t0\n',
#  'MGME1\t0\n',
#  'TRAPPC10\t0\n',
#  'FAP\t0\n',
#  'HSD17B1\t0\n',
#  'UBAP1\t0\n',
#  'ADRA2C\t0\n',
#  'UCN3\t0\n',
#  'SLC4A1\t0\n',
#  'ISOC1\t0\n',
#  'GORASP1\t0\n',
#  'PAK1\t0\n',
#  'KRT20\t0\n',
#  'NCOA6\t0\n',
#  'CHMP4C\t0\n',
#  'ELMOD3\t0\n',
#  'FABP1\t0\n',
#  'ERH\t0\n',
#  'STAT5B\t0\n',
#  'PDCD5\t0\n',
#  'MAP1A\t0\n',
#  'GLB1L3\t0\n',
#  'DAB2\t0\n',
#  'PAK6\t0\n',
#  'SENP3\t0\n',
#  'SSBP4\t0\n',
#  'ATP5PD\t0\n',
#  'KAT8\t0\n',
#  'LMO2\t0\n',
#  'UBE2L6\t0\n',
#  'SLC22A4\t0\n',
#  'TEX10\t0\n',
#  'TMEM141\t0\n',
#  'IGKV3D-7\t0\n',
#  'UNG\t0\n',
#  'NINJ2\t0\n',
#  'B3GNT7\t0\n',
#  'NCKIPSD\t0\n',
#  'FKTN\t0\n',
#  'ADH1C\t0\n',
#  'SKP1\t0\n',
#  'CLASP1\t0\n',
#  'WRN\t0\n',
#  'ELMO3\t0\n',
#  'NACA2\t0\n',
#  'HAAO\t0\n',
#  'KCNN4\t0\n',
#  'RAB11B\t0\n',
#  'IMPG1\t0\n',
#  'HNRNPDL\t0\n',
#  'TOP3A\t0\n',
#  'IMPA1\t0\n',
#  'FKBPL\t0\n',
#  'LAYN\t0\n',
#  'MORC3\t0\n',
#  'PI16\t0\n',
#  'MEPE\t0\n',
#  'CDK5R2\t0\n',
#  'SLX4\t0\n',
#  'CEBPA\t0\n',
#  'MIR19B2\t0\n',
#  'VEGFC\t0\n',
#  'DVL2\t0\n',
#  'HNRNPCP2\t0\n',
#  'SAP25\t0\n',
#  'HLX\t0\n',
#  'C11orf52\t0\n',
#  'MDFIC\t0\n',
#  'CAPN10\t0\n',
#  'MAPRE1\t0\n',
#  'PPP4R1L\t0\n',
#  'JMJD8\t0\n',
#  'ATP11C\t0\n',
#  'PCDHB3\t0\n',
#  'SPG21\t0\n',
#  'RHOU\t0\n',
#  'FBXL5\t0\n',
#  'ACOT13\t0\n',
#  'ATP6V0D1\t0\n',
#  'KCNJ3\t0\n',
#  'DYNLL2\t0\n',
#  'PRPF40A\t0\n',
#  'ARHGAP20\t0\n',
#  'GRM1\t0\n',
#  'GCAT\t0\n',
#  'GREM2\t0\n',
#  'PABIR1\t0\n',
#  'C7\t0\n',
#  'ZNF784\t0\n',
#  'ITGA2B\t0\n',
#  'SIRPA\t0\n',
#  'PTDSS2\t0\n',
#  'NPC1\t0\n',
#  'HOXA13\t0\n',
#  'CLTB\t0\n',
#  'SEMA6B\t0\n',
#  'GPR55\t0\n',
#  'TTC9B\t0\n',
#  'SNAP47\t0\n',
#  'ZNF616\t0\n',
#  'C16orf92\t0\n',
#  'TRIM14\t0\n',
#  'DNAJC5B\t0\n',
#  'FLNB\t0\n',
#  'SLC2A1\t0\n',
#  'DNAJC3\t0\n',
#  'POU2F2\t0\n',
#  'AMZ1\t0\n',
#  'HOXB5\t0\n',
#  'TET2\t0\n',
#  'MAN2A2\t0\n',
#  'CAMK2D\t0\n',
#  'ARHGAP36\t0\n',
#  'SHBG\t0\n',
#  'GINS3\t0\n',
#  'NDC1\t0\n',
#  'GLI2\t0\n',
#  'PDP1\t0\n',
#  'SGO1\t0\n',
#  'NHP2\t0\n',
#  'TYROBP\t0\n',
#  'BSPRY\t0\n',
#  'TMED4\t0\n',
#  'GDE1\t0\n',
#  'PI4K2B\t0\n',
#  'NBEA\t0\n',
#  'MIR18A\t0\n',
#  'YTHDF3\t0\n',
#  'SHOC2\t0\n',
#  'ARPC1A\t0\n',
#  'TIAM2\t0\n',
#  'C9orf43\t0\n',
#  'RCC1\t0\n',
#  'DIS3L2\t0\n',
#  'RXRA\t0\n',
#  'PPP4R1\t0\n',
#  'MEP1B\t0\n',
#  'TRIP10\t0\n',
#  'IL2RB\t0\n',
#  'NPTN\t0\n',
#  'FGFR3\t0\n',
#  'GDPD4\t0\n',
#  'CLIC5\t0\n',
#  'IL1RN\t0\n',
#  'PDZRN3\t0\n',
#  'LRRC41\t0\n',
#  'PLN\t0\n',
#  'SLC16A10\t0\n',
#  'PLAC9\t0\n',
#  'ORC3\t0\n',
#  'ZNF101\t0\n',
#  'ATP5F1B\t0\n',
#  'LAMB3\t0\n',
#  'NSMCE1\t0\n',
#  'RNF139\t0\n',
#  'CNR1\t0\n',
#  'MSL1\t0\n',
#  'TECTB\t0\n',
#  'GPR3\t0\n',
#  'APOE\t0\n',
#  'SEPTIN4\t0\n',
#  'DNAJB8\t0\n',
#  'TAF13\t0\n',
#  'PIK3C2A\t0\n',
#  'DICER1-AS1\t0\n',
#  'ALG2\t0\n',
#  'TMEM138\t0\n',
#  'ZNF821\t0\n',
#  'SCRN1\t0\n',
#  'KIR2DS3\t0\n',
#  'CLUH\t0\n',
#  'SEC24B\t0\n',
#  'MYBPC2\t0\n',
#  'DLGAP4\t0\n',
#  'MPPE1\t0\n',
#  'ODAPH\t0\n',
#  'MIR92A1\t0\n',
#  'KYNU\t0\n',
#  'PWP1\t0\n',
#  'MLPH\t0\n',
#  'TWNK\t0\n',
#  'ZNF786\t0\n',
#  'CHD7\t0\n',
#  'CAMK4\t0\n',
#  'TENT5B\t0\n',
#  'DDR1\t0\n',
#  'SPCS3\t0\n',
#  'BTLA\t0\n',
#  'POTEE\t0\n',
#  'ARFGEF3\t0\n',
#  'TRIM33\t0\n',
#  'ZNF430\t0\n',
#  'NR5A2\t0\n',
#  'NDUFAF4\t0\n',
#  'SIPA1L2\t0\n',
#  'MATN1\t0\n',
#  'TEN1\t0\n',
#  'ASB15\t0\n',
#  'PPP1R42\t0\n',
#  'CYFIP1\t0\n',
#  'SH3BGRL3\t0\n',
#  'CAPS\t0\n',
#  'HNRNPUL1\t0\n',
#  'PHETA1\t0\n',
#  'SETD9\t0\n',
#  'NPPB\t0\n',
#  'SCHIP1\t0\n',
#  'ASB6\t0\n',
#  'FGL1\t0\n',
#  'BGLAP\t0\n',
#  'C8B\t0\n',
#  'ANKRD2\t0\n',
#  'CRAT\t0\n',
#  'MACC1\t0\n',
#  'PRDX4\t0\n',
#  'MED11\t0\n',
#  'NFIC\t0\n',
#  'TMEM60\t0\n',
#  'GSTA4\t0\n',
#  'ADRB3\t0\n',
#  'STAM2\t0\n',
#  'DRG1\t0\n',
#  'DEFB127\t0\n',
#  'GFOD2\t0\n',
#  'TMEM45A\t0\n',
#  'STK11IP\t0\n',
#  'NSA2\t0\n',
#  'CCAR1\t0\n',
#  'MRPS11\t0\n',
#  'ABI1\t0\n',
#  'CBX1\t0\n',
#  'UBE2NL\t0\n',
#  'ORM1\t0\n',
#  'MRPL37\t0\n',
#  'CDK5RAP3\t0\n',
#  'PAPLN\t0\n',
#  'UBE2E2\t0\n',
#  'VRK2\t0\n',
#  'MYPN\t0\n',
#  'GET1\t0\n',
#  'RACGAP1\t0\n',
#  'SCNM1\t0\n',
#  'AICDA\t0\n',
#  'PANK1\t0\n',
#  'ZNF497\t0\n',
#  'ESCO2\t0\n',
#  'GRSF1\t0\n',
#  'PBXIP1\t0\n',
#  'IPO11\t0\n',
#  'SFTA2\t0\n',
#  'ELMOD1\t0\n',
#  'CLASRP\t0\n',
#  'MED4\t0\n',
#  'ZSCAN18\t0\n',
#  'PPP2R5C\t0\n',
#  'SUMF1\t0\n',
#  'MINK1\t0\n',
#  'ZDHHC5\t0\n',
#  'RBM7\t0\n',
#  'GRM8\t0\n',
#  'MND1\t0\n',
#  'AASDHPPT\t0\n',
#  'CCDC9B\t0\n',
#  'PBX4\t0\n',
#  'DEFB1\t0\n',
#  'ZC3H7A\t0\n',
#  'HIPK1\t0\n',
#  'DOCK3\t0\n',
#  'SYTL5\t0\n',
#  'AFG1L\t0\n',
#  'CRB1\t0\n',
#  'TNFSF13\t0\n',
#  'RNF216P1\t0\n',
#  'CNN3\t0\n',
#  'DHCR7\t0\n',
#  'ATP6V0B\t0\n',
#  'BEX5\t0\n',
#  'TLE2\t0\n',
#  'RBM4B\t0\n',
#  'PLEKHG7\t0\n',
#  'SMIM1\t0\n',
#  'RIPK2\t0\n',
#  'GYG2\t0\n',
#  'UBE2U\t0\n',
#  'CMTR1\t0\n',
#  'ADRM1\t0\n',
#  'GPX8\t0\n',
#  'LHFPL1\t0\n',
#  'PTPRCAP\t0\n',
#  'VCL\t0\n',
#  'RGS12\t0\n',
#  'PLEKHS1\t0\n',
#  'ZNF236\t0\n',
#  'PPEF2\t0\n',
#  'ZC2HC1B\t0\n',
#  'DENND2A\t0\n',
#  'RSPH4A\t0\n',
#  'GALNT9\t0\n',
#  'STAU1\t0\n',
#  'ARMH1\t0\n',
#  'NTRK3\t0\n',
#  'NIPAL3\t0\n',
#  'CSNK1G1\t0\n',
#  'RNF133\t0\n',
#  'SGSM2\t0\n',
#  'ADCYAP1\t0\n',
#  'POMT1\t0\n',
#  'ZNF131\t0\n',
#  'DMRT3\t0\n',
#  'NOM1\t0\n',
#  'ANGPTL6\t0\n',
#  'TAF9B\t0\n',
#  'UBE2M\t0\n',
#  'SLC6A3\t0\n',
#  'TMEM33\t0\n',
#  'CTSG\t0\n',
#  'KLHL3\t0\n',
#  'CMTM3\t0\n',
#  'SET\t0\n',
#  'THEM6\t0\n',
#  'GRAMD2A\t0\n',
#  'EPN3\t0\n',
#  'COMMD2\t0\n',
#  'MGAT4C\t0\n',
#  'SNRNP27\t0\n',
#  'KRT28\t0\n',
#  'SCIN\t0\n',
#  'MOCS1\t0\n',
#  'ATXN7L1\t0\n',
#  'EMG1\t0\n',
#  'SYCP1\t0\n',
#  'FAM161A\t0\n',
#  'PRKCQ\t0\n',
#  'AGTRAP\t0\n',
#  'CHRM2\t0\n',
#  'CKMT2\t0\n',
#  'AFG3L2\t0\n',
#  'LRSAM1\t0\n',
#  'SETDB2\t0\n',
#  'GLA\t0\n',
#  'OR13C3\t0\n',
#  'CADPS2\t0\n',
#  'RNF157\t0\n',
#  'TG\t0\n',
#  'CASP2\t0\n',
#  'ZNF792\t0\n',
#  'SLC47A1\t0\n',
#  'RRP7A\t0\n',
#  'MIR122\t0\n',
#  'B3GNT5\t0\n',
#  'THADA\t0\n',
#  'GTF2H5\t0\n',
#  'ZFTRAF1\t0\n',
#  'EVI5\t0\n',
#  'ZMYND8\t0\n',
#  'RPP40\t0\n',
#  'RSAD1\t0\n',
#  'TRAT1\t0\n',
#  'ZNF714\t0\n',
#  'CACNA2D1\t0\n',
#  'CBY2\t0\n',
#  'NAT8B\t0\n',
#  'VPS45\t0\n',
#  'SLC35A5\t0\n',
#  'H2BC1\t0\n',
#  'TBC1D12\t0\n',
#  'NIN\t0\n',
#  'SETD1A\t0\n',
#  'ARVCF\t0\n',
#  'HESX1\t0\n',
#  'SLC30A6\t0\n',
#  'MAEL\t0\n',
#  'TINF2\t0\n',
#  'TMEM163\t0\n',
#  'CHAF1A\t0\n',
#  'COMMD10\t0\n',
#  'LRRC56\t0\n',
#  'PLEKHM1\t0\n',
#  'LSM2\t0\n',
#  'CLSTN2\t0\n',
#  'PWWP2A\t0\n',
#  'SYK\t0\n',
#  'NDUFB2\t0\n',
#  'SLC2A4\t0\n',
#  'C4orf33\t0\n',
#  'SURF1\t0\n',
#  'CEP290\t0\n',
#  'FAM221A\t0\n',
#  'KLHL33\t0\n',
#  'KIF3A\t0\n',
#  'OPCML\t0\n',
#  'SNX12\t0\n',
#  'PSENEN\t0\n',
#  'LILRB4\t0\n',
#  'FAM157A\t0\n',
#  'TOR1AIP1\t0\n',
#  'CNOT7\t0\n',
#  'IGFBP6\t0\n',
#  'TSPAN12\t0\n',
#  'CIPC\t0\n',
#  'KCNK15\t0\n',
#  'POLK\t0\n',
#  'PRKAG3\t0\n',
#  'LSM11\t0\n',
#  'NDP\t0\n',
#  'ITM2C\t0\n',
#  'DYRK1B\t0\n',
#  'CHIA\t0\n',
#  'EREG\t0\n',
#  'YIPF2\t0\n',
#  'RHOT2\t0\n',
#  'DPM2\t0\n',
#  'DCST1\t0\n',
#  'NEK11\t0\n',
#  'GPR15\t0\n',
#  'HFE\t0\n',
#  'MTARC2\t0\n',
#  'NT5C1B\t0\n',
#  'CCPG1\t0\n',
#  'HS3ST4\t0\n',
#  'MRPL27\t0\n',
#  'FRK\t0\n',
#  'TESPA1\t0\n',
#  'GADD45A\t0\n',
#  'GABARAPL2\t0\n',
#  'ANKRD12\t0\n',
#  'NUP160\t0\n',
#  'STK4\t0\n',
#  'ARR3\t0\n',
#  'ADAL\t0\n',
#  'MAOB\t0\n',
#  'PTPN14\t0\n',
#  'GSTP1\t0\n',
#  'TACC2\t0\n',
#  'MIR155\t0\n',
#  'IRAK3\t0\n',
#  'AURKB\t0\n',
#  'KLHL9\t0\n',
#  'RPS6KA3\t0\n',
#  'ZNF490\t0\n',
#  'CPB2\t0\n',
#  'NAALADL2\t0\n',
#  'TDRD3\t0\n',
#  'ZNF804A\t0\n',
#  'IL7\t0\n',
#  'GPX1\t0\n',
#  'LRAT\t0\n',
#  'EFNA3\t0\n',
#  'ERICH1\t0\n',
#  'ST7\t0\n',
#  'TMSB15A\t0\n',
#  'TNMD\t0\n',
#  'UCHL3\t0\n',
#  'EMSY\t0\n',
#  'OSGEP\t0\n',
#  'ING4\t0\n',
#  'WDFY4\t0\n',
#  'LCN1\t0\n',
#  'KCNQ2\t0\n',
#  'CD40LG\t0\n',
#  'PCSK4\t0\n',
#  'ASB16\t0\n',
#  'SYT9\t0\n',
#  'TBP\t0\n',
#  'DNAJB13\t0\n',
#  'RNF185\t0\n',
#  'CORO1A\t0\n',
#  'OXCT1\t0\n',
#  'SCGB1C1\t0\n',
#  'MFSD11\t0\n',
#  'PPIL3\t0\n',
#  'NDUFAF1\t0\n',
#  'BTN3A3\t0\n',
#  'C12orf29\t0\n',
#  'WASH3P\t0\n',
#  'ATP2A3\t0\n',
#  'MMGT1\t0\n',
#  'TMPRSS11D\t0\n',
#  'LRRC42\t0\n',
#  'MTMR7\t0\n',
#  'LPIN3\t0\n',
#  'SYT7\t0\n',
#  'MAGEA9\t0\n',
#  'SLC39A4\t0\n',
#  'MRPL20\t0\n',
#  'HOXC4\t0\n',
#  'CLDND1\t0\n',
#  'ZNF671\t0\n',
#  'GON7\t0\n',
#  'TSPAN8\t0\n',
#  'ACER1\t0\n',
#  'NRAP\t0\n',
#  'COL3A1\t0\n',
#  'ZNF627\t0\n',
#  'CCDC191\t0\n',
#  'SNX18\t0\n',
#  'SALL2\t0\n',
#  'ACRV1\t0\n',
#  'IDH1\t0\n',
#  'RAVER1\t0\n',
#  'CHMP1A\t0\n',
#  'CENPA\t0\n',
#  'OXLD1\t0\n',
#  'NFE2L1\t0\n',
#  'PTPN23\t0\n',
#  'MAP4K5\t0\n',
#  'NDST4\t0\n',
#  'PPP2R5A\t0\n',
#  'FBXO46\t0\n',
#  'LACRT\t0\n',
#  'C1orf68\t0\n',
#  'CNOT4\t0\n',
#  'TMUB1\t0\n',
#  'TCEAL3\t0\n',
#  'PGM2L1\t0\n',
#  'CPS1\t0\n',
#  'UBAC2\t0\n',
#  'PGGT1B\t0\n',
#  'CHGA\t0\n',
#  'RTCA\t0\n',
#  'FAIM\t0\n',
#  'ERC2\t0\n',
#  'SNRNP48\t0\n',
#  'NUDC\t0\n',
#  'SEC22A\t0\n',
#  'ASF1B\t0\n',
#  'SPATA48\t0\n',
#  'CCDC51\t0\n',
#  'ZNRF2P1\t0\n',
#  'EIF2AK2\t0\n',
#  'SLC25A30\t0\n',
#  'ZNF202\t0\n',
#  'TSPAN4\t0\n',
#  'GC\t0\n',
#  'GP2\t0\n',
#  'DYNLT3\t0\n',
#  'FNDC1\t0\n',
#  'MICALL1\t0\n',
#  'PFAS\t0\n',
#  'C3orf33\t0\n',
#  'ZIC1\t0\n',
#  'C11orf54\t0\n',
#  'KRTAP10-6\t0\n',
#  'GPATCH4\t0\n',
#  'MTUS1\t0\n',
#  'H2BC13\t0\n',
#  'PDE4DIP\t0\n',
#  'LAMC2\t0\n',
#  'CCDC88A\t0\n',
#  'TRPM6\t0\n',
#  'TTC23L\t0\n',
#  'MAT2B\t0\n',
#  'DCTN5\t0\n',
#  'LOXL2\t0\n',
#  'CCDC68\t0\n',
#  'ZFYVE26\t0\n',
#  'MEIKIN\t0\n',
#  'HOXB13\t0\n',
#  'KIF15\t0\n',
#  'PANK2\t0\n',
#  'MRPL55\t0\n',
#  'DOK2\t0\n',
#  'NGLY1\t0\n',
#  'TRAF7\t0\n',
#  'BCL11B\t0\n',
#  'GSK3B\t0\n',
#  'WDR87\t0\n',
#  'OBP2A\t0\n',
#  'JRK\t0\n',
#  'FGF9\t0\n',
#  'ERAP1\t0\n',
#  'PLA2G3\t0\n',
#  'GTF2H4\t0\n',
#  'CXADR\t0\n',
#  'SVOP\t0\n',
#  'HK1\t0\n',
#  'SNAI2\t0\n',
#  'CSNK2A3\t0\n',
#  'PLCB1\t0\n',
#  'NACAD\t0\n',
#  'MSTO1\t0\n',
#  'MIR92A2\t0\n',
#  'FAAP24\t0\n',
#  'FAM193A\t0\n',
#  'TMEFF2\t0\n',
#  'MYL4\t0\n',
#  'ENTPD3\t0\n',
#  'DEPP1\t0\n',
#  'MICAL1\t0\n',
#  'SFMBT1\t0\n',
#  'ADM\t0\n',
#  'RHBDL1\t0\n',
#  'POLR2B\t0\n',
#  'NAGK\t0\n',
#  'AP3B1\t0\n',
#  'ERRFI1\t0\n',
#  'XRCC5\t0\n',
#  'TRIM60\t0\n',
#  'WDR55\t0\n',
#  'A2ML1\t0\n',
#  ...]

# %%
len(res) - 144
# Out:
# 14263

# %%
topscoring = res[14263:]

# %%
genes_to_plot = [g.split('\t')[0] for g in topscoring]
scores = [g.split('\t')[1].rstrip('\n') for g in topscoring]

# %%
interactome_res_subnet = nx.subgraph(interactome_net,genes_to_plot)

# %%
seeds=['IL6', 'IL6ST','IL16', 'IL1B', 'IL17D', 'IL18', 'IL20', 'TNF', 'LIF', 'OSM', 'CCL2', 'CCL3', 'CCL5', 'CCL7', 'CXCL1', 'CXCL2', 'CXCL3', 'CXCL8', 'CX3CL1', 'IGF1', 'GDF5', 'TGFB1', 'GDF6', 'PMP2', 'VEGFA']


attributes_seed = dict(zip(genes_to_plot, [1 if gene in seeds else 0 for gene in genes_to_plot]))
attributes_score = dict(zip(genes_to_plot, scores))

# %%
nx.set_node_attributes(interactome_res_subnet, attributes_seed, "seed")
nx.set_node_attributes(interactome_res_subnet, attributes_score, "score")

# %%
grpl.visualize_network(interactome_res_subnet,node_color_attribute='seed',
                       layout='auto',node_size=300,
                       figure_size=(35,30),
                       node_annotation=True)
